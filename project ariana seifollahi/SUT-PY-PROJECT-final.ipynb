# %% [markdown]
#   <div dir=rtl>
#     <img src="https://github.com/MoeeinAali/FOP2023-Python-Project-SUT/blob/main/public/Logo.png?raw=true" style="width: 20%;">
#   </div>
#   <br>
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         <font face="IranSansX" size=6>
#         <b>پروژه درس مبانی برنامه‌سازی پایتون</b>
#             <font face="IranSansX" size=3>(نیم‌سال اول سال تحصیلی 02-03)</font>
#         </font><br>
#         <br>
#                 <font face="IranSansX" size=4>نام استاد: <b>آرمان ملک‌زاده </b></font>
#         <br>
#         <font face="IranSansX" size=4>سردستیاران آموزشی: <b>ایمان محمدی - علی ثالثی </b></font>
#         <br>
#         <font face="IranSansX" size=4>مسئول پروژه: <b> معین آعلی</b></font>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         </font>
#                     <font face="IranSansX" size=5 color=#006bcf>
#                         <b>اطلاعات دانشجو</b>
#                         <br>
#     </font>
#                 <font face="IranSansX" size=4 color=#006bcf>نام و نام‌خانوادگی:
#                     <b>
# <!--                         معین  -->
# <!--                         آعلی -->
#                     </b>
#         </font>
#         <br>
#         </font>
#                 <font face="IranSansX" size=4 color=#006bcf>شماره دانشجویی:
# <!--     <b>401105561</b> -->
#         </font>
#     </font>
# </div>

# %% [markdown]
# Ariana Seifollahi
# 402100837

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         <b><font color=#cf1f00 size=4>توضیحات پروژه</font></b>
#         <hr/>
#        پروژه‌ی تحلیل داده که برای دانشجویان درس مبانی برنامه‌نویسی طراحی شده است، یک فرصت فوق‌العاده برای آشنایی با مفاهیم و فرایندهای مهم در حوزه‌ی تحلیل داده‌ها به دانشجویان ارائه می‌دهد. این پروژه برای دانشجوان این امکان را فراهم می‌کند تا با مراحل مختلف تحلیل داده آشنا شوند، از جمع‌آوری داده‌ها و تمیزکاری آن‌ها تا استفاده از الگوریتم‌ها و روش‌های تحلیلی متنوع برای استخراج اطلاعات مفید و الگوهای مهم. این پروژه نه‌تنها به دانشجویان این امکان را می‌دهد تا مهارت‌های برنامه نویسی خود را به کار بگیرند، بلکه با استفاده از ابزارهای نرم‌افزاری و تکنولوژی‌های مختلف، اطلاعات تحلیلی خود را به شیوه‌های مختلف و قابل فهم برای دیگران نمایش دهند. این پروژه از طریق تحلیل داده‌ها، دانشجویان را با ابزارها و فنون مرتبط با این حوزه آشنا می‌کند و امکان پیدا کردن الگوها و اطلاعات ارزشمند در داده‌ها را فراهم می‌سازد که این موارد می‌تواند در فرآیند تصمیم‌گیری‌های آینده‌ی شغلی و تحصیلی دانشجویان تأثیرگذار باشد.
#         <br>
#         دیتاست مورد استفاده در این پروژه شامل اطلاعات تعدادی از خانه‌های شهر تهران است که برای فروش آگهی شده بودند.
#         این دیتاست شامل مواردی همچون محله، قیمت، متراژ و بعضی از ویژگی‌های خاص هر خانه مانند انباری، آسانسور و ... است.
#          <br>
#         در این پروژه ما داد‌ها را تحلیل می‌کنیم و اطلاعاتی از وضعیت خانه‌های آگهی شده‌ی شهر تهران بدست می‌آوریم.
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         <b><font color=#cf1f00 size=4>نحوه تحویل پروژه</font></b>
#         <hr/>
#         دیتاست مورد استفاده در این پروژه در قالب یک فایل csv در اختیار شما قرار داده شده است.
#         <br>
#         برای تحویل پروژه لازم است که این NoteBook را تا ساعت 23:59 تاریخ 27 دی‌ماه تکمیل کرده و فایل آن را در کوئرا آپلود کنید.
#         دقت کنید که این پروژه 3 نمره از بارم‌بندی کل درس را شامل می‌شود، درنتیجه انتظار می‌روند به نسبت نمره‌ی اختصاص داده شده، برای پروژه وقت گذاشته شود.
#         دقت کنید که پس از اپلود پروژه در کوئرا، باید پروژه را برای تیم تدریس درس ارائه دهید، پس سعی کنید کدهایی که می‌زنید را متوجه شوید و به خوبی درک کنید و برای ارائه‌ی آن‌ها آماده باشید.
#         <br>
#         توجه داشته باشید که در صورت ابراز تقلب شما هنگام تحویل پروژه، مطابق با آیین‌نامه‌ی درس با شما برخورد خواهد شد.
#         <br>
#         شما
#         می‌توانید از هوش مصنوعی و گوگل برای یادگیری مطالب این پروژه استفاده کنید، اما الزامی است که کدهای این NoteBook توسط خودتان زده شده باشد.
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         <b><font color=#cf0000 size=4>نصب کتابخانه‌های مورد نیاز</font><b>
#         <hr/>
#             برای نصب کتابخانه‌های مورد نیاز در این پروژه، از pip استفاده می‌کنیم. بنابراین در ابتدا لازم است از نصب بودن pip برروی سیستم خود مطمئن شوید.
#             <a href="https://phoenixnap.com/kb/install-pip-windows">می‌توانید از این لینک کمک بگیرید.</a>
# <br>
#         حال که pip را نصب کردید می‌توانید اقدام به نصب کتابخانه‌های مورد نیاز بکنید.
#         در این پروژه پیش‌بینی می‌شود که از نیازمند استفاده از کتابخانه‌هایی همچون numpy و pandas و matplotlib و seaborn باشید.
#         البته شما آزاد هستید از دیگر کتابخانه‌های پایتون نیز استفاده کنید.
# > >             برای نصف کتابخانه‌های فوق به کمک pip، می‌توانید از دستور زیر استفاده کنید:
#     </font>
# </div>

# %%
# !pip install matplotlib seaborn pandas numpy
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.4)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (1.24.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         <b>
#         <font color=#006bcf size=5>فاز اول پروژه: </font>
#         <font color=#006bcf size=5>
#         Data Analysis
#         </font>
#         </b>
#         <br><br>
#          <font face="IranSansX" size=3>
# بخش تحلیل داده‌ها در این پروژه، به عنوان یک قسمت بسیار مهم و جذاب، به دانشجو فرصت می‌دهد تا از مفاهیم و تکنیک‌های بنیادی در حوزه‌ی تحلیل داده‌ها استفاده کند. این بخش شامل فرآیندهای مربوط به جمع‌آوری، تمیزکاری، تحلیل و نمایش داده‌ها است که از روش‌ها و ابزارهای مختلفی می‌توان برای این منظور استفاده کرد. با اعمال الگوریتم‌ها، روش‌های مختلف محاسباتی و ابزارهای نرم‌افزاری مناسب، دانشجوان قادر خواهند بود تا داده‌های خود را تجزیه و تحلیل کرده، الگوها و اطلاعات مفیدی را کشف کرده و درک عمیق‌تری از داده‌ها و مسائل مورد بررسی در پروژه خود پیدا کنند. این فرآیند به آن‌ها کمک می‌کند تا تصمیم‌گیری‌های بهتری بر اساس داده‌های موجود انجام دهند و نتایج موثرتری را به‌دست آورند.            </font>
#         <hr/>
#         <hr/>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# کتابخانه‌هایی که در مرحله قبل نصب کردید را داخل نوت‌بوک import کنید و برای هر کدام یک نام مخفف مانند sns, plt, np, pd و... در نظر بگیرید.    </font>
# </div>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# دیتاست موجود در پروژه که یک فایل csv است را به صورت یک دیتافریم در متغیری به نام df بخوانید.
#     </font>
# </div>

# %%
df = pd.read_csv("housePrice.csv")

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ابعاد (تعداد سطرها و تعداد ستون‌ها) دیتافریم را به صورت یک tuple نمایش دهید.
#     </font>
# </div>

# %%
print(df.shape)
# Out:
# (3479, 8)

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         دیتافریم را چاپ کنید.
#     </font>
# </div>

# %%
pd.set_option('display.width', 1000)
print(df.to_string(index=False))
# Out:
#             Area  Room  Parking  Warehouse  Elevator                       Address        Price  Price(USD)
#               63     1     True       True      True                       Shahran 1.850000e+09    61666.67
#               60     1     True       True      True                       Shahran 1.850000e+09    61666.67
#               79     2     True       True      True                        Pardis 5.500000e+08    18333.33
#               95     2     True       True      True                 Shahrake Qods 9.025000e+08    30083.33
#              123     2     True       True      True                Shahrake Gharb 7.000000e+09   233333.33
#               70     2     True       True     False    North Program Organization 2.050000e+09    68333.33
#               87     2     True       True      True                        Pardis 6.000000e+08    20000.00
#               59     1     True       True      True                       Shahran 2.150000e+09    71666.67
#               54     2     True       True     False                      Andisheh 4.930000e+08    16433.33
#               71     1     True       True      True        West Ferdows Boulevard 2.370000e+09    79000.00
#               68     2     True       True      True        West Ferdows Boulevard 2.450000e+09    81666.67
#               64     1     True       True      True                        Narmak 2.100000e+09    70000.00
#               54     1    False       True      True                        Narmak 1.690000e+09    56333.33
#              136     3     True       True      True                   Saadat Abad 1.100000e+10   366666.67
#               95     2     True       True      True                         Zafar 5.000000e+09   166666.67
#               63     1    False       True     False                    Islamshahr 5.700000e+08    19000.00
#              155     3     True       True      True                        Narmak 6.700000e+09   223333.33
#               64     2    False       True     False                       Pirouzi 1.450000e+09    48333.33
#              140     3     True       True      True        West Ferdows Boulevard 6.400000e+09   213333.33
#               42     1    False       True     False                       Pirouzi 1.390000e+09    46333.33
#               93     2     True       True      True                Shahrake Gharb 7.000000e+09   233333.33
#               87     2     True       True      True       Shahrake Shahid Bagheri 2.500000e+09    83333.33
#               65     1     True       True      True                       Shahran 1.880000e+09    62666.67
#               99     2     True       True      True                     Moniriyeh 2.277000e+09    75900.00
#              105     2     True       True      True                   Saadat Abad 7.150000e+09   238333.33
#              160     3     True       True      True                      Velenjak 1.494500e+10   498166.67
#               77     2     True       True      True                       Amirieh 1.771000e+09    59033.33
#              123     2     True       True      True                       Pirouzi 4.059000e+09   135300.00
#              110     2     True       True      True            Southern Janatabad 6.300000e+08    21000.00
#              100     2     True       True      True        West Ferdows Boulevard 3.200000e+09   106666.67
#               90     2    False       True     False                      Salsabil 1.500000e+09    50000.00
#               49     1     True       True      True        West Ferdows Boulevard 2.200000e+09    73333.33
#               96     2     True       True      True                     Zargandeh 7.872000e+09   262400.00
#               67     2     True       True     False                   Feiz Garden 2.350000e+09    78333.33
#               68     2     True       True      True        West Ferdows Boulevard 2.500000e+09    83333.33
#               62     1     True      False      True            Water Organization 2.150000e+09    71666.67
#               55     1     True       True      True        West Ferdows Boulevard 2.150000e+09    71666.67
#              110     2     True       True      True        West Ferdows Boulevard 3.750000e+09   125000.00
#              129     2     True       True      True        West Ferdows Boulevard 5.250000e+09   175000.00
#              109     2     True       True      True        West Ferdows Boulevard 4.830000e+09   161000.00
#               58     1     True       True      True                   Saadat Abad 3.400000e+09   113333.33
#               55     1     True       True      True                   Saadat Abad 3.850000e+09   128333.33
#              150     2    False       True      True                 Shahrake Qods 1.200000e+09    40000.00
#               60     2     True       True      True                           NaN 2.650000e+09    88333.33
#              130     3     True       True     False                      ShahrAra 5.000000e+09   166666.67
#               88     2     True       True      True                         Gisha 4.750000e+09   158333.33
#               51     1     True       True      True                         Gisha 2.980000e+09    99333.33
#              113     3     True       True     False                Shahrake Gharb 7.000000e+09   233333.33
#              110     2     True       True      True                           Ray 2.035000e+09    67833.33
#               60     1     True       True      True                     Abbasabad 2.460000e+09    82000.00
#               98     2     True       True      True                        Pardis 5.400000e+08    18000.00
#               62     2    False      False      True                   Ostad Moein 1.450000e+09    48333.33
#              150     3     True       True      True                     Farmanieh 1.000000e+10   333333.33
#               75     2    False      False     False                        Parand 6.350000e+08    21166.67
#               61     1     True       True     False                         Punak 2.030000e+09    67666.67
#               61     1     True       True     False                         Punak 2.030000e+09    67666.67
#               72     2     True       True      True                       Shahran 2.350000e+09    78333.33
#              100     2     True       True      True                 Qasr-od-Dasht 3.000000e+09   100000.00
#              122     3     True       True      True                      Aqdasieh 7.200000e+09   240000.00
#              215     3     True       True      True                      Pakdasht 1.750000e+09    58333.33
#              101     2     True       True      True                       Railway 3.300000e+09   110000.00
#               67     2     True       True      True                         Punak 2.800000e+09    93333.33
#               72     2     True       True     False                         Punak 2.200000e+09    73333.33
#               63     1     True       True     False                         Punak 2.200000e+09    73333.33
#               75     2     True       True     False                         Punak 2.200000e+09    73333.33
#              109     2     True       True      True                       Shahran 3.500000e+09   116666.67
#              122     2     True       True      True                      Aqdasieh 7.000000e+09   233333.33
#               70     1     True       True      True             Central Janatabad 3.100000e+09   103333.33
#               60     1     True       True      True        West Ferdows Boulevard 2.450000e+09    81666.67
#               53     1     True       True     False        East Ferdows Boulevard 1.920000e+09    64000.00
#               90     1    False       True     False           Pakdasht KhatunAbad 8.500000e+08    28333.33
#               72     2     True       True      True                       Amirieh 1.650000e+09    55000.00
#               74     2     True       True      True                       Amirieh 1.700000e+09    56666.67
#               88     3    False      False      True                        Parand 5.600000e+08    18666.67
#               63     1     True       True      True                         Punak 2.150000e+09    71666.67
#              114     3     True       True      True                    Sattarkhan 5.500000e+09   183333.33
#              151     3     True       True      True                   Saadat Abad 1.020000e+10   340000.00
#               42     1     True      False      True                       Shahran 1.760000e+09    58666.67
#               74     2     True       True      True                       Amirieh 1.700000e+09    56666.67
#               88     3    False      False      True                        Parand 5.600000e+08    18666.67
#               63     1     True       True      True                         Punak 2.150000e+09    71666.67
#              114     3     True       True      True                    Sattarkhan 5.500000e+09   183333.33
#              151     3     True       True      True                   Saadat Abad 1.020000e+10   340000.00
#               42     1     True      False      True                       Shahran 1.760000e+09    58666.67
#              300     3     True       True     False                     Baghestan 1.500000e+09    50000.00
#              110     2     True       True      True        West Ferdows Boulevard 3.730000e+09   124333.33
#              100     2    False      False     False                 Shahrake Qods 6.200000e+08    20666.67
#              140     1    False      False     False                      Shahryar 5.800000e+08    19333.33
#               70     2     True       True      True            Northern Janatabad 3.050000e+09   101666.67
#               60     2     True       True     False        West Ferdows Boulevard 2.000000e+09    66666.67
#               76     2     True       True      True    North Program Organization 2.600000e+09    86666.67
#              148     3     True       True      True                     Daryan No 5.990000e+09   199666.67
#               75     2     True       True      True    North Program Organization 2.300000e+09    76666.67
#               40     1     True       True     False                       Pirouzi 1.300000e+09    43333.33
#               65     2     True       True      True Southern Program Organization 2.270000e+09    75666.67
#              140     3     True       True      True                        Rudhen 4.000000e+09   133333.33
#              110     2     True       True      True                     West Pars 4.000000e+09   133333.33
#               70     2     True      False      True                      Afsarieh 1.650000e+09    55000.00
#              128     3     True       True      True                     Marzdaran 6.700000e+09   223333.33
#               94     2     True       True      True                        Parand 5.800000e+08    19333.33
#               67     1     True       True      True                         Punak 2.300000e+09    76666.67
#               75     1     True       True      True                 Shahrake Qods 6.500000e+08    21666.67
#              130     2     True       True      True                        Dorous 1.690000e+10   563333.33
#               40     0    False      False     False                 Shahrake Qods 2.480000e+08     8266.67
#               97     2     True       True      True                        Pardis 5.100000e+08    17000.00
#              110     2     True       True      True                       Shahran 3.850000e+09   128333.33
#              150     3     True       True      True                     Sadeghieh 6.000000e+09   200000.00
#               75     2    False      False     False                  Chahardangeh 7.800000e+08    26000.00
#              137     3     True       True      True                      ShahrAra 7.200000e+09   240000.00
#               85     2     True       True      True                        Parand 4.100000e+08    13666.67
#               68     2    False       True     False                      Pakdasht 4.300000e+08    14333.33
#               78     2    False       True     False                    Baqershahr 8.000000e+08    26666.67
#               85     2     True       True      True                        Parand 5.450000e+08    18166.67
#              100     2     True       True     False                        Parand 1.280000e+09    42666.67
#               71     2     True       True      True                         Punak 2.800000e+09    93333.33
#              140     3     True       True      True                         Gisha 1.120000e+10   373333.33
#              136     3     True       True     False                        Parand 7.500000e+08    25000.00
#               48     1    False      False     False                       Jeyhoon 8.500000e+08    28333.33
#              100     2     True       True      True                       Lavizan 3.300000e+09   110000.00
#               82     2     True      False      True                    Shams Abad 3.280000e+09   109333.33
#              120     3     True       True      True                        Fatemi 4.800000e+09   160000.00
#              139     3     True       True      True                         Gisha 7.300000e+09   243333.33
#              110     3     True       True      True           Keshavarz Boulevard 3.950000e+09   131666.67
#               78     2    False      False      True                        Parand 3.700000e+08    12333.33
#               79     2    False      False     False                     Baghestan 7.500000e+08    25000.00
#               66     2     True       True      True                      Salsabil 1.725000e+09    57500.00
#               78     2     True       True      True                      Kahrizak 7.800000e+08    26000.00
#               85     2     True       True      True                      Shahryar 1.419000e+09    47300.00
#              100     2     True       True     False                       Qarchak 1.200000e+09    40000.00
#               80     2     True       True      True           Northren Jamalzadeh 3.600000e+09   120000.00
#               44     1     True       True     False                      Salsabil 1.050000e+09    35000.00
#              120     2     True       True     False                      Shahryar 1.200000e+09    40000.00
#               50     1    False       True     False                 Shahrake Qods 3.400000e+08    11333.33
#              121     3     True       True     False                   Ostad Moein 3.300000e+09   110000.00
#               80     2     True       True      True                    Azarbaijan 2.800000e+09    93333.33
#               70     2    False       True      True                         Bahar 1.200000e+09    40000.00
#              160     1    False      False     False                       Qarchak 3.600000e+06      120.00
#               40     0    False      False     False                      Pakdasht 1.650000e+08     5500.00
#               88     2     True       True      True                       Railway 2.860000e+09    95333.33
#              141     3     True       True      True     Persian Gulf Martyrs Lake 3.810000e+09   127000.00
#              140     3     True       True      True     Persian Gulf Martyrs Lake 1.790000e+09    59666.67
#              120     2     True       True      True     Persian Gulf Martyrs Lake 1.530000e+09    51000.00
#               66     2    False       True     False                      Beryanak 1.000000e+09    33333.33
#               70     2     True       True      True                         Punak 3.500000e+09   116666.67
#               75     2     True      False      True                    Heshmatieh 3.000000e+09   100000.00
#               70     2    False       True      True                   Elm-o-Sanat 1.800000e+09    60000.00
#              150     3     True       True      True                   Saadat Abad 2.000000e+10   666666.67
#               95     2     True       True      True                      Golestan 9.500000e+08    31666.67
#              127     2     True       True      True            Southern Janatabad 6.000000e+09   200000.00
#              123     3     True       True      True                  Shahr-e-Ziba 3.700000e+09   123333.33
#               63     2     True       True      True            Southern Janatabad 2.000000e+09    66666.67
#               90     2     True       True      True                         Punak 3.050000e+09   101666.67
#              105     2     True       True      True                        Pardis 6.050000e+08    20166.67
#              180     3     True       True      True                      Pasdaran 9.900000e+09   330000.00
#              120     3     True      False      True                       Pirouzi 3.700000e+09   123333.33
#               65     2     True       True      True                   Feiz Garden 2.500000e+09    83333.33
#              158     3     True       True      True                     Farmanieh 1.048000e+10   349333.33
#              144     3     True       True      True                    Chardivari 7.632000e+09   254400.00
#              144     3     True       True      True                         Punak 7.632000e+09   254400.00
#              130     3     True       True      True                    Gheitarieh 1.230000e+10   410000.00
#              245     3     True       True      True                     Farmanieh 2.695000e+10   898333.33
#              190     3     True       True      True                     Kamranieh 2.430000e+10   810000.00
#               63     2     True       True      True             Central Janatabad 3.000000e+09   100000.00
#               75     2     True       True      True        East Ferdows Boulevard 2.100000e+09    70000.00
#               88     2     True      False      True                       Gholhak 4.700000e+09   156666.67
#              108     2     True       True      True                      Pasdaran 9.180000e+09   306000.00
#              117     2     True       True      True                    Islamshahr 1.579500e+09    52650.00
#              200     3     True       True      True                      Pasdaran 1.200000e+10   400000.00
#               65     1     True       True     False                       Pirouzi 1.750000e+09    58333.33
#               90     2     True       True      True             Central Janatabad 3.780000e+09   126000.00
#              125     2     True       True      True                        Heravi 8.100000e+09   270000.00
#              140     3     True       True      True                        Heravi 9.100000e+09   303333.33
#               71     2    False       True      True                       Hashemi 1.550000e+09    51666.67
#               71     2    False       True      True                       Jeyhoon 1.640000e+09    54666.67
#              236     4     True       True      True                    Gheitarieh 2.000000e+10   666666.67
#               67     2     True       True      True             Central Janatabad 2.750000e+09    91666.67
#               60     1     True       True      True                         Punak 1.750000e+09    58333.33
#              220     3     True       True      True                        Heravi 1.540000e+10   513333.33
#               44     1     True       True     False                      Andisheh 3.500000e+08    11666.67
#               68     1     True       True      True                        Heravi 4.115000e+09   137166.67
#              100     2     True       True      True                      Pasdaran 8.000000e+09   266666.67
#               86     2     True       True      True                        Pardis 5.800000e+08    19333.33
#               84     2     True       True      True                        Pardis 5.600000e+08    18666.67
#               94     2     True       True      True                        Heravi 4.800000e+09   160000.00
#               55     1    False       True     False        West Ferdows Boulevard 1.550000e+09    51666.67
#              113     2     True       True      True                   Saadat Abad 7.500000e+09   250000.00
#               71     2     True       True      True                    Islamshahr 6.300000e+08    21000.00
#               70     2     True       True     False               Dehkade Olampic 2.000000e+09    66666.67
#              200     3     True       True      True                      Golestan 2.400000e+09    80000.00
#              106     2     True       True      True                      Golestan 1.100000e+09    36666.67
#              320     4     True       True      True                   Saadat Abad 2.400000e+10   800000.00
#              114     2     True       True      True                     West Pars 3.820000e+09   127333.33
#              100     2     True       True      True                         Punak 6.000000e+09   200000.00
#              122     2     True       True      True                   Saadat Abad 5.800000e+09   193333.33
#              200     2     True       True     False                      Damavand 3.500000e+09   116666.67
#              154     3     True       True      True                   Saadat Abad 1.230000e+10   410000.00
#              210     3     True       True      True                      Pasdaran 1.575000e+10   525000.00
#              200     3     True       True      True        East Ferdows Boulevard 1.100000e+10   366666.67
#               65     1     True       True      True            Southern Janatabad 3.000000e+09   100000.00
#              124     3     True       True      True                       Pirouzi 3.968000e+09   132266.67
#               83     2     True       True      True                      Republic 1.909000e+09    63633.33
#              270     4     True       True      True                     Farmanieh 3.780000e+10  1260000.00
#              104     2     True       True      True        East Ferdows Boulevard 5.700000e+09   190000.00
#              150     3     True       True      True                    Zaferanieh 1.049000e+10   349666.67
#              103     3     True       True      True        West Ferdows Boulevard 3.200000e+09   106666.67
#               48     1     True       True      True        West Ferdows Boulevard 1.920000e+09    64000.00
#              165     3     True       True      True                    Gheitarieh 1.230000e+10   410000.00
#              135     2     True       True     False                    Gheitarieh 7.400000e+09   246666.67
#               86     2     True       True      True                   Saadat Abad 6.200000e+09   206666.67
#               75     2     True       True      True        East Ferdows Boulevard 2.350000e+09    78333.33
#               58     1     True       True      True        East Ferdows Boulevard 1.850000e+09    61666.67
#              125     2     True       True      True                Shahrake Gharb 2.150000e+10   716666.67
#               82     2     True       True      True       Qazvin Imamzadeh Hassan 1.886000e+09    62866.67
#               58     2     True       True      True                       Shahran 2.200000e+09    73333.33
#              101     2     True       True      True                      Beryanak 2.323000e+09    77433.33
#               90     2     True       True      True                      Niavaran 6.800000e+09   226666.67
#              180     3     True       True      True                     Farmanieh 2.070000e+10   690000.00
#              132     3     True       True      True                    Gheitarieh 6.250000e+09   208333.33
#               81     2     True       True      True                       Valiasr 1.863000e+09    62100.00
#              153     3     True       True      True                      Pasdaran 1.300000e+10   433333.33
#              166     3     True       True      True                     Qalandari 1.250000e+10   416666.67
#              200     3     True       True      True                      Pasdaran 1.700000e+10   566666.67
#              113     2     True       True      True                      Pasdaran 8.500000e+09   283333.33
#              100     2     True       True      True                       Valiasr 2.300000e+09    76666.67
#               80     2     True       True      True             Central Janatabad 3.350000e+09   111666.67
#               76     2     True       True      True                       Jeyhoon 2.000000e+09    66666.67
#              128     3     True       True      True                         Punak 5.700000e+09   190000.00
#              210     3     True       True      True                Shahrake Gharb 2.700000e+10   900000.00
#              140     2     True       True      True                Shahrake Gharb 1.260000e+10   420000.00
#               74     2     True       True      True                  Amir Bahador 1.702000e+09    56733.33
#               75     1     True       True      True             Central Janatabad 3.000000e+09   100000.00
#              120     2     True       True      True                      Pasdaran 7.500000e+09   250000.00
#              120     2     True       True      True                      Pasdaran 7.500000e+09   250000.00
#               85     2     True       True      True                    Ekhtiarieh 5.000000e+09   166666.67
#              105     2     True       True      True                        Pardis 7.000000e+08    23333.33
#              175     3     True       True      True                     Farmanieh 1.560000e+10   520000.00
#              170     3     True       True      True                     Farmanieh 1.535000e+10   511666.67
#               58     1     True       True      True                       Ekbatan 2.810000e+09    93666.67
#               75     2     True       True      True                        Parand 3.950000e+08    13166.67
#              160     3     True       True      True                    Gheitarieh 1.510000e+10   503333.33
#               62     1     True       True      True                       Shahran 1.850000e+09    61666.67
#               93     2     True       True      True                        Rudhen 1.450000e+09    48333.33
#               75     2     True       True      True                    Islamshahr 7.150000e+08    23833.33
#               86     2     True       True     False                    Islamshahr 1.200000e+09    40000.00
#              120     2     True       True      True Southern Program Organization 4.260000e+09   142000.00
#               95     2     True       True      True                      Andisheh 1.500000e+09    50000.00
#               70     2     True       True     False        West Ferdows Boulevard 2.120000e+09    70666.67
#               75     2     True       True     False        East Ferdows Boulevard 2.000000e+09    66666.67
#               81     2     True      False      True                        Pardis 5.900000e+08    19666.67
#               65     1     True       True     False        West Ferdows Boulevard 1.930000e+09    64333.33
#               75     2     True       True      True        East Ferdows Boulevard 2.730000e+09    91000.00
#              106     2     True       True     False        East Ferdows Boulevard 3.150000e+09   105000.00
#              115     2     True       True      True        East Ferdows Boulevard 4.600000e+09   153333.33
#              100     2     True       True      True                  Shahr-e-Ziba 3.000000e+09   100000.00
#              118     2     True       True      True        East Ferdows Boulevard 4.500000e+09   150000.00
#              116     2     True       True      True        East Ferdows Boulevard 5.100000e+09   170000.00
#               76     2     True       True      True                  Shahr-e-Ziba 2.200000e+09    73333.33
#               74     2     True       True     False        East Ferdows Boulevard 2.300000e+09    76666.67
#               96     2     True       True      True                   Saadat Abad 4.500000e+09   150000.00
#               87     2     True       True      True                        Pardis 6.250000e+08    20833.33
#               43     1     True       True     False            Northern Janatabad 1.620000e+09    54000.00
#              155     3     True       True      True                      Niavaran 1.705000e+10   568333.33
#               53     1     True       True      True        East Ferdows Boulevard 1.920000e+09    64000.00
#              160     3     True       True      True                     Farmanieh 1.760000e+10   586666.67
#               78     2     True       True      True                  Shahr-e-Ziba 2.250000e+09    75000.00
#              230     3     True       True      True                      Niavaran 2.530000e+10   843333.33
#               55     1     True       True      True        West Ferdows Boulevard 1.850000e+09    61666.67
#              120     2     True       True     False                   Saadat Abad 1.170000e+10   390000.00
#               78     2     True       True      True            Southern Janatabad 3.600000e+09   120000.00
#               95     2     True       True      True            Southern Janatabad 4.400000e+09   146666.67
#              170     3     True       True      True                    Gheitarieh 1.540000e+10   513333.33
#              175     3     True       True      True                Shahrake Gharb 2.275000e+10   758333.33
#              115     3     True       True      True                         Punak 4.500000e+09   150000.00
#              113     2     True       True      True                         Punak 4.300000e+09   143333.33
#               85     2     True       True      True                         Punak 3.380000e+09   112666.67
#              140     3     True       True      True                   Saadat Abad 1.000000e+10   333333.33
#               90     2     True       True      True                   Saadat Abad 6.500000e+09   216666.67
#               63     1     True      False     False                         Punak 2.200000e+09    73333.33
#               75     2     True       True      True             Central Janatabad 3.220000e+09   107333.33
#              130     3     True       True      True                         Punak 6.240000e+09   208000.00
#               91     2     True       True      True                         Punak 3.350000e+09   111666.67
#              121     3     True       True      True     Persian Gulf Martyrs Lake 3.650000e+09   121666.67
#              140     3     True       True      True                   Saadat Abad 1.550000e+10   516666.67
#              126     2     True       True      True        East Ferdows Boulevard 5.500000e+09   183333.33
#              450     2     True       True     False                        Absard 4.200000e+09   140000.00
#              500     2     True       True     False                        Absard 3.900000e+09   130000.00
#              110     1     True       True      True                      Pasdaran 6.600000e+09   220000.00
#              145     3     True       True      True                      Haft Tir 4.700000e+09   156666.67
#               81     2     True       True      True                 Shahrake Qods 8.100000e+08    27000.00
#               64     2     True       True      True                  Shahr-e-Ziba 2.200000e+09    73333.33
#              112     2     True       True      True                  Shahr-e-Ziba 3.680000e+09   122666.67
#              192     3     True       True      True                     Marzdaran 1.267000e+10   422333.33
#              164     3     True       True      True                     Marzdaran 1.000000e+10   333333.33
#              135     3     True       True      True                      Pasdaran 8.100000e+09   270000.00
#              170     3     True       True      True                     Mahallati 9.200000e+09   306666.67
#              130     3     True       True      True                     Mahallati 5.200000e+09   173333.33
#               84     2     True       True      True                       Shahran 3.400000e+09   113333.33
#               82     2     True       True      True                       Shahran 3.550000e+09   118333.33
#              265     3     True       True      True                     Farmanieh 2.000000e+10   666666.67
#               60     1     True       True      True            Southern Janatabad 1.950000e+09    65000.00
#              145     3     True       True      True                      Pasdaran 1.550000e+10   516666.67
#               65     1    False       True      True            Southern Janatabad 2.000000e+09    66666.67
#               60     1     True       True     False            Southern Janatabad 2.280000e+09    76000.00
#               63     2     True       True      True            Southern Janatabad 2.000000e+09    66666.67
#               70     2     True       True      True            Southern Janatabad 1.950000e+09    65000.00
#               92     2     True       True      True                   Feiz Garden 3.900000e+09   130000.00
#               98     2     True       True      True                      Pasdaran 7.800000e+09   260000.00
#               62     1     True       True      True            Southern Janatabad 2.280000e+09    76000.00
#               65     1     True       True      True                         Punak 2.900000e+09    96666.67
#               90     2     True       True      True                         Ozgol 5.000000e+09   166666.67
#               59     2     True       True      True            Southern Janatabad 1.900000e+09    63333.33
#               63     2     True       True      True            Southern Janatabad 2.000000e+09    66666.67
#               60     2     True       True      True            Southern Janatabad 2.200000e+09    73333.33
#               70     2     True       True      True            Southern Janatabad 2.500000e+09    83333.33
#               60     1     True       True      True            Southern Janatabad 2.200000e+09    73333.33
#              165     3     True       True      True                      Pasdaran 1.050000e+10   350000.00
#              135     2     True       True      True                    Zaferanieh 1.750000e+10   583333.33
#               65     1     True       True      True            Southern Janatabad 2.000000e+09    66666.67
#               60     1     True       True      True            Southern Janatabad 2.250000e+09    75000.00
#               60     1     True       True      True            Southern Janatabad 2.250000e+09    75000.00
#               86     2     True       True      True            Southern Janatabad 3.600000e+09   120000.00
#              109     2     True       True      True                        Heravi 6.000000e+09   200000.00
#               98     2     True       True     False                        Narmak 2.842000e+09    94733.33
#               80     2     True       True      True             Central Janatabad 3.120000e+09   104000.00
#              143     3     True       True      True                    Gheitarieh 8.860000e+09   295333.33
#               95     2     True       True      True                   Saadat Abad 4.550000e+09   151666.67
#               86     2     True       True      True                         Punak 3.700000e+09   123333.33
#              160     3     True       True      True                    Gheitarieh 1.000000e+10   333333.33
#              200     3     True       True      True                      Pasdaran 1.658000e+10   552666.67
#               74     1     True       True      True                         Punak 3.250000e+09   108333.33
#              350     3     True       True      True                    Zaferanieh 5.250000e+10  1750000.00
#               87     2     True       True      True            Northern Janatabad 3.550000e+09   118333.33
#               82     2     True       True      True        West Ferdows Boulevard 3.450000e+09   115000.00
#               55     1     True       True      True                  Shahr-e-Ziba 2.490000e+09    83000.00
#              148     3     True       True      True                    Ekhtiarieh 8.400000e+09   280000.00
#               55     1     True      False      True                  Shahr-e-Ziba 2.020000e+09    67333.33
#              100     2     True       True     False            Southern Janatabad 3.800000e+09   126666.67
#               55     1    False       True     False        West Ferdows Boulevard 1.550000e+09    51666.67
#              130     3     True       True      True             Central Janatabad 5.300000e+09   176666.67
#              335     4     True       True      True                   Saadat Abad 3.350000e+10  1116666.67
#              320     4     True       True      True                   Saadat Abad 4.000000e+10  1333333.33
#              192     3     True       True      True                   Saadat Abad 1.950000e+10   650000.00
#              100     2     True       True      True                    Gheitarieh 8.000000e+09   266666.67
#              148     3     True       True      True                   Saadat Abad 1.480000e+10   493333.33
#              145     2     True       True      True                Shahrake Gharb 1.470000e+10   490000.00
#              192     4     True       True      True                   Saadat Abad 2.200000e+10   733333.33
#              235     3     True       True      True    North Program Organization 1.645000e+10   548333.33
#              225     3     True       True      True                        Heravi 1.575000e+10   525000.00
#              221     4     True       True      True                   Saadat Abad 2.500000e+10   833333.33
#              312     4     True       True      True                     Farmanieh 4.500000e+10  1500000.00
#              188     3     True       True      True                         Ozgol 1.767200e+10   589066.67
#              170     2     True       True      True                     Farmanieh 1.240000e+10   413333.33
#              198     3     True       True      True                     Farmanieh 2.772000e+10   924000.00
#               80     2     True       True      True    North Program Organization 3.100000e+09   103333.33
#              170     3     True       True      True                      Niavaran 1.870000e+10   623333.33
#              110     2     True       True      True                       Tajrish 6.600000e+09   220000.00
#              650     2     True       True     False                        Absard 5.200000e+09   173333.33
#              200     3     True       True      True                   Saadat Abad 1.200000e+10   400000.00
#              101     3     True       True      True                    Ekhtiarieh 6.500000e+09   216666.67
#              104     2     True       True      True                   Feiz Garden 3.850000e+09   128333.33
#               70     2     True       True      True            Northern Janatabad 3.200000e+09   106666.67
#               76     2     True       True     False                  Shahr-e-Ziba 2.570000e+09    85666.67
#              110     2     True       True      True                   Feiz Garden 4.300000e+09   143333.33
#              160     2     True       True      True                      Pasdaran 1.620000e+10   540000.00
#              179     3     True       True      True                        Dorous 1.380000e+10   460000.00
#              256     3     True       True      True                        Dorous 1.850000e+10   616666.67
#               90     2     True       True      True                   Feiz Garden 3.850000e+09   128333.33
#               77     2     True       True      True                  Shahr-e-Ziba 2.570000e+09    85666.67
#               96     2     True       True      True                      Pasdaran 5.600000e+09   186666.67
#               75     1     True       True      True             Central Janatabad 3.250000e+09   108333.33
#               79     2     True       True      True                        Abazar 3.000000e+09   100000.00
#               67     1     True       True      True                   Saadat Abad 3.400000e+09   113333.33
#              125     2     True       True      True                  Shahr-e-Ziba 6.400000e+09   213333.33
#               75     2     True       True     False                  Shahr-e-Ziba 1.890000e+09    63000.00
#               75     2     True       True     False                  Shahr-e-Ziba 1.890000e+09    63000.00
#               91     2     True       True      True                   Saadat Abad 5.400000e+09   180000.00
#              105     2     True       True      True                        Parand 1.417500e+09    47250.00
#               66     2     True       True      True                   Ostad Moein 1.585000e+09    52833.33
#               86     2     True       True      True            Southern Janatabad 3.270000e+09   109000.00
#               72     2     True       True     False            Northern Janatabad 2.380000e+09    79333.33
#              148     2     True      False      True                       Koohsar 4.500000e+09   150000.00
#               84     2     True       True      True                   Saadat Abad 4.600000e+09   153333.33
#              128     2     True       True      True                      Niavaran 1.280000e+10   426666.67
#               65     1     True       True      True        West Ferdows Boulevard 3.900000e+09   130000.00
#              140     3     True       True      True                      Pasdaran 1.180000e+10   393333.33
#              115     2     True       True      True                    Ekhtiarieh 7.400000e+09   246666.67
#              105     2     True       True      True                   Saadat Abad 5.700000e+09   190000.00
#               87     2     True       True      True                        Pardis 6.500000e+08    21666.67
#               75     2     True       True     False                  Shahr-e-Ziba 1.890000e+09    63000.00
#               60     1     True       True      True     Persian Gulf Martyrs Lake 8.750000e+08    29166.67
#               68     1     True       True      True Southern Program Organization 2.630000e+09    87666.67
#               49     1     True       True      True        West Ferdows Boulevard 2.200000e+09    73333.33
#              103     2     True       True      True                        Hekmat 9.270000e+09   309000.00
#               55     1     True       True      True        West Ferdows Boulevard 2.200000e+09    73333.33
#              140     3     True       True      True                         Punak 7.700000e+09   256666.67
#              257     4     True       True      True     Persian Gulf Martyrs Lake 1.285000e+10   428333.33
#               82     2     True       True      True                         Punak 4.018000e+09   133933.33
#              167     3     True       True      True                         Punak 1.068800e+10   356266.67
#               53     1    False       True     False        West Ferdows Boulevard 1.640000e+09    54666.67
#               51     1    False       True     False        West Ferdows Boulevard 1.550000e+09    51666.67
#               54     1     True       True     False        West Ferdows Boulevard 2.130000e+09    71000.00
#               82     2     True       True      True                    Sattarkhan 4.100000e+09   136666.67
#               75     2     True       True      True        West Ferdows Boulevard 2.800000e+09    93333.33
#               98     2     True       True      True        West Ferdows Boulevard 4.520000e+09   150666.67
#               75     2     True       True     False                  Shahr-e-Ziba 1.890000e+09    63000.00
#               70     1     True       True      True                      Niavaran 5.600000e+09   186666.67
#               75     2     True       True     False                  Shahr-e-Ziba 1.890000e+09    63000.00
#               64     1     True       True      True                       Ekbatan 3.700000e+09   123333.33
#               85     2     True       True      True                       Jeyhoon 2.100000e+09    70000.00
#               48     1    False       True     False                      Parastar 9.800000e+08    32666.67
#               75     2     True       True     False                  Shahr-e-Ziba 1.890000e+09    63000.00
#              246     3     True       True      True                    Ekhtiarieh 2.250000e+10   750000.00
#              168     3     True       True      True                    Gheitarieh 1.400000e+10   466666.67
#              280     4     True       True      True                   Saadat Abad 3.850000e+10  1283333.33
#               75     2     True       True     False                  Shahr-e-Ziba 1.890000e+09    63000.00
#               84     2     True       True      True                        Pardis 6.800000e+08    22666.67
#               75     2     True       True     False                  Shahr-e-Ziba 1.890000e+09    63000.00
#              108     2     True       True      True                         Gisha 5.180000e+09   172666.67
#               62     1     True       True      True                  Shahr-e-Ziba 2.580000e+09    86000.00
#               70     2     True       True      True            Southern Janatabad 3.370000e+09   112333.33
#              180     3     True       True      True                      Pasdaran 9.900000e+09   330000.00
#              135     3     True       True      True                        Abazar 6.480000e+09   216000.00
#               75     2     True       True     False                  Shahr-e-Ziba 1.890000e+09    63000.00
#              108     2     True       True      True                     Farmanieh 6.200000e+09   206666.67
#               91     2     True       True      True                    Ekhtiarieh 5.180000e+09   172666.67
#              120     2     True       True      True                    Gheitarieh 8.900000e+09   296666.67
#              112     2     True       True     False                    Gheitarieh 7.500000e+09   250000.00
#               75     2     True       True     False                  Shahr-e-Ziba 1.890000e+09    63000.00
#              123     2     True       True      True                       Pirouzi 4.059000e+09   135300.00
#               69     2     True       True      True                       Pirouzi 1.800000e+09    60000.00
#              400     5     True       True     False                       Lavasan 8.500000e+10  2833333.33
#              660     5     True       True     False                       Lavasan 5.500000e+10  1833333.33
#               66     1     True      False      True                       Pirouzi 1.850000e+09    61666.67
#               80     2     True       True      True                   Ostad Moein 2.150000e+09    71666.67
#               44     1     True       True     False                       Pirouzi 8.800000e+08    29333.33
#              180     3     True       True      True        East Ferdows Boulevard 9.360000e+09   312000.00
#              164     3     True       True      True        East Ferdows Boulevard 9.840000e+09   328000.00
#              213     3     True       True      True        East Ferdows Boulevard 1.448400e+10   482800.00
#              100     2     True       True      True                  Shahr-e-Ziba 3.400000e+09   113333.33
#               75     2     True       True     False                  Shahr-e-Ziba 1.890000e+09    63000.00
#              300     3     True       True      True                      Niavaran 5.550000e+10  1850000.00
#              126     3     True       True      True                   Ostad Moein 3.000000e+09   100000.00
#               85     2     True       True      True                      Majidieh 2.500000e+09    83333.33
# ...
#               71     1    False       True      True                        Pardis 5.400000e+08    18000.00
#              175     3     True       True      True                          Kook 1.050000e+10   350000.00
#              145     3     True       True      True                Shahrake Gharb 1.050000e+10   350000.00
#              285     4     True       True      True                Shahrake Gharb 2.850000e+10   950000.00
#              125     3     True       True      True                Shahrake Gharb 1.125000e+10   375000.00
#              115     2     True       True      True                Shahrake Gharb 1.200000e+10   400000.00
#               59     1     True       True      True                      Andisheh 7.080000e+08    23600.00
#               89     3     True       True      True                        Parand 4.300000e+08    14333.33
#               78     2     True      False      True                       Jeyhoon 2.250000e+09    75000.00
#               65     1     True       True      True                        Parand 3.400000e+08    11333.33
#               78     2     True       True      True                        Parand 4.800000e+08    16000.00
#               82     2     True       True      True             Central Janatabad 3.000000e+09   100000.00
#              125     2    False       True     False                    Gheitarieh 1.550000e+09    51666.67
#               60     2    False       True      True                      Vahidieh 1.280000e+09    42666.67
#               57     2    False       True     False                      Salsabil 1.200000e+09    40000.00
#               66     2    False       True     False                      Afsarieh 1.120000e+09    37333.33
#               80     2     True       True      True        West Ferdows Boulevard 3.000000e+09   100000.00
#               46     1     True       True      True                       Shahran 1.700000e+09    56666.67
#               80     2     True       True      True        East Ferdows Boulevard 3.000000e+09   100000.00
#               73     2     True       True      True            Southern Janatabad 3.060000e+09   102000.00
#              115     2    False      False     False            Northern Janatabad 5.175000e+09   172500.00
#               65     2     True       True     False                     West Pars 1.950000e+09    65000.00
#               72     2     True       True      True            Southern Janatabad 2.550000e+09    85000.00
#               80     2     True       True      True            Southern Janatabad 3.000000e+09   100000.00
#              135     3     True       True      True                           NaN 1.500000e+09    50000.00
#               80     2     True       True      True             Central Janatabad 3.000000e+09   100000.00
#               97     2     True       True      True                        Narmak 4.000000e+09   133333.33
#              150     3     True       True      True                      Niavaran 1.100000e+10   366666.67
#              175     3     True       True      True                      ShahrAra 7.800000e+09   260000.00
#               74     1    False       True      True                        Parand 4.800000e+08    16000.00
#              157     3     True       True      True                     Marzdaran 1.020000e+10   340000.00
#               92     2     True       True      True                   Feiz Garden 3.350000e+09   111666.67
#              190     3     True       True      True                      Pasdaran 1.235000e+10   411666.67
#              110     2     True       True      True                      Pasdaran 8.800000e+09   293333.33
#               50     1    False       True     False                       Pirouzi 1.100000e+09    36666.67
#              197     3     True       True      True                     Marzdaran 1.556300e+10   518766.67
#              107     2     True       True      True                         Chidz 8.600000e+09   286666.67
#               78     2     True       True      True                     Farmanieh 7.200000e+09   240000.00
#               46     1     True       True      True             Central Janatabad 1.950000e+09    65000.00
#              112     2     True       True      True                    Mahmoudieh 8.400000e+09   280000.00
#               60     1    False       True     False                    Tehran Now 1.500000e+09    50000.00
#              128     3     True       True      True                     Marzdaran 6.700000e+09   223333.33
#              193     3     True       True      True                          Kook 1.300000e+10   433333.33
#              120     2     True       True      True                      Niavaran 9.000000e+09   300000.00
#              115     2     True       True      True                         Ghoba 8.150000e+09   271666.67
#               95     2     True       True      True            Southern Janatabad 3.300000e+09   110000.00
#               92     2     True       True      True             Central Janatabad 3.400000e+09   113333.33
#               71     2     True       True     False        West Ferdows Boulevard 2.000000e+09    66666.67
#               95     2     True       True      True                      Damavand 1.750000e+09    58333.33
#               40     1    False       True     False                      Salsabil 6.300000e+08    21000.00
#               52     1     True       True      True                         Punak 2.360000e+09    78666.67
#               84     2     True       True      True                      Salsabil 1.900000e+09    63333.33
#               80     2     True       True      True                       Amirieh 1.800000e+09    60000.00
#               58     1    False       True     False                      Salsabil 7.150000e+08    23833.33
#               68     2     True       True      True                       Shahran 2.270000e+09    75666.67
#               90     2     True       True      True            Southern Janatabad 3.350000e+09   111666.67
#               65     1    False       True     False                      Republic 1.400000e+09    46666.67
#              200     2    False      False     False                        Rudhen 2.850000e+09    95000.00
#               72     2     True       True      True                       Amirieh 1.670000e+09    55666.67
#               80     2     True       True      True                 Qasr-od-Dasht 1.800000e+09    60000.00
#               71     2     True       True      True                       Amirieh 1.650000e+09    55000.00
#               86     2     True       True      True                       Amirieh 1.980000e+09    66000.00
#               75     2    False       True      True                        Parand 3.450000e+08    11500.00
#               54     1     True       True      True        West Ferdows Boulevard 2.250000e+10   750000.00
#               60     1     True       True      True                  Shahr-e-Ziba 1.960000e+09    65333.33
#              105     3     True       True      True        East Ferdows Boulevard 5.830000e+09   194333.33
#               72     2     True       True      True                        Abazar 3.350000e+09   111666.67
#              186     3     True       True      True                      Pasdaran 9.300000e+09   310000.00
#              110     2     True       True      True                        Heravi 6.050000e+09   201666.67
#               90     2     True       True      True            Southern Janatabad 3.350000e+09   111666.67
#               78     2     True      False      True                           NaN 7.400000e+08    24666.67
#               84     2     True       True      True                    Islamshahr 8.550000e+08    28500.00
#               53     1    False      False     False                      Kahrizak 4.500000e+08    15000.00
#               63     3    False       True     False                     Javadiyeh 1.450000e+09    48333.33
#               53     1    False       True     False                       Shahran 1.470000e+09    49000.00
#              105     2     True       True      True            Southern Janatabad 3.500000e+09   116666.67
#              100     2     True       True      True                   Saadat Abad 4.550000e+09   151666.67
#               93     2     True       True      True                   Saadat Abad 3.900000e+09   130000.00
#               83     3    False      False     False                        Atabak 1.286500e+09    42883.33
#              135     3     True       True      True                   Saadat Abad 7.500000e+09   250000.00
#               65     1    False      False      True                   Saadat Abad 3.490000e+09   116333.33
#              100     2     True       True      True                   Saadat Abad 4.480000e+09   149333.33
#               80     2    False      False     False                      Damavand 7.500000e+08    25000.00
#               90     2     True       True      True                   Saadat Abad 5.250000e+09   175000.00
#               73     2     True       True      True             Central Janatabad 1.900000e+09    63333.33
#               82     2     True       True      True                       Shahran 3.600000e+09   120000.00
#              148     3     True       True      True                   Yousef Abad 8.140000e+09   271333.33
#               90     2     True      False      True                       Shahran 3.150000e+09   105000.00
#              112     2     True       True      True                       Darabad 7.000000e+09   233333.33
#               45     1    False      False      True                   Si Metri Ji 8.900000e+09   296666.67
#               70     2     True       True     False                        Narmak 1.850000e+09    61666.67
#              107     2     True       True      True                      Mirdamad 7.597000e+09   253233.33
#               37     1     True       True      True                     Tehransar 1.180000e+09    39333.33
#               65     1     True       True      True                       Jeyhoon 1.725000e+09    57500.00
#               76     2     True       True      True                  Shahr-e-Ziba 2.850000e+09    95000.00
#               66     2    False       True     False                   Yakhchiabad 1.000000e+09    33333.33
#              130     3     True       True      True     Persian Gulf Martyrs Lake 8.650000e+08    28833.33
#               63     3     True       True     False                        Shoosh 1.200000e+09    40000.00
#               75     2    False       True     False                 Shahrake Quds 5.000000e+08    16666.67
#               52     1     True      False     False                       Jeyhoon 1.200000e+09    40000.00
#               86     3    False       True      True                        Parand 2.750000e+08     9166.67
#               58     1    False      False      True                        Parand 2.460000e+08     8200.00
#               76     2     True       True      True        West Ferdows Boulevard 2.600000e+09    86666.67
#               87     2     True       True      True                           NaN 6.800000e+08    22666.67
#               54     0    False      False     False                 Shahrake Qods 4.700000e+08    15666.67
#              140     3     True       True      True                     Daryan No 6.300000e+09   210000.00
#               74     2    False      False      True                        Parand 3.130000e+08    10433.33
#              186     3     True       True      True                      Velenjak 1.500000e+10   500000.00
#              140     3     True       True      True                        Mehran 8.400000e+09   280000.00
#              114     2     True       True      True     Persian Gulf Martyrs Lake 4.000000e+09   133333.33
#               51     1    False      False      True                   Ostad Moein 1.100000e+09    36666.67
#              180     3     True       True      True                     Kamranieh 1.400000e+10   466666.67
#               70     1     True       True      True                         Punak 3.500000e+09   116666.67
#              120     3     True       True      True                    Sattarkhan 5.400000e+09   180000.00
#              137     3     True       True      True                         Punak 6.850000e+09   228333.33
#               92     2     True       True      True                       Shahran 3.220000e+09   107333.33
#               45     1     True       True     False        West Ferdows Boulevard 1.650000e+09    55000.00
#               68     2    False       True      True                     Waterfall 1.000000e+09    33333.33
#               80     2     True       True      True                         Punak 3.760000e+09   125333.33
#               85     2    False       True      True             Central Janatabad 3.200000e+09   106666.67
#               88     2     True       True      True             Central Janatabad 4.000000e+09   133333.33
#              118     2     True       True      True                        Mehran 7.080000e+09   236000.00
#              180     3     True       True     False                     Marzdaran 1.080000e+10   360000.00
#               60     1     True       True     False        West Ferdows Boulevard 1.860000e+09    62000.00
#               80     2    False       True      True                      Shahryar 4.100000e+08    13666.67
#               86     2    False       True     False                     Vahidiyeh 5.200000e+08    17333.33
#              123     3     True       True      True                      Velenjak 1.250000e+10   416666.67
#              148     3     True       True      True                     Daryan No 6.000000e+09   200000.00
#               80     2     True       True      True                   Ostad Moein 2.250000e+09    75000.00
#               58     1    False      False      True                        Parand 3.250000e+08    10833.33
#               55     1     True       True      True                         Punak 2.300000e+09    76666.67
#               60     1     True       True      True        West Ferdows Boulevard 1.950000e+09    65000.00
#              133     3     True      False      True                Shahrake Gharb 1.000000e+10   333333.33
#               94     2    False       True      True                      Damavand 5.950000e+08    19833.33
#               68     2    False       True      True                      Beryanak 1.258000e+09    41933.33
#               61     2    False       True     False                      Andisheh 4.600000e+08    15333.33
#               75     2     True       True      True        West Ferdows Boulevard 2.650000e+09    88333.33
#               81     2     True       True      True        West Ferdows Boulevard 4.455000e+09   148500.00
#               74     2     True       True      True                        Mehran 4.070000e+09   135666.67
#               97     2     True       True      True                       Shahran 2.700000e+09    90000.00
#               94     2     True       True      True                      Niavaran 8.450000e+09   281666.67
#              113     3     True       True      True                   Ostad Moein 3.170000e+09   105666.67
#               63     1     True       True     False                   Feiz Garden 1.890000e+09    63000.00
#               86     2     True       True      True            Southern Janatabad 3.500000e+09   116666.67
#               83     2     True       True      True                      Niavaran 6.800000e+09   226666.67
#               75     2    False      False     False                        Parand 3.650000e+08    12166.67
#              105     2     True       True      True                        Dorous 5.600000e+09   186666.67
#               82     2    False       True      True                        Parand 3.600000e+08    12000.00

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ده سطر اول دیتافریم را چاپ کنید.
#     </font>
# </div>

# %%
df.head(10)
# Out:
#   Area  Room  Parking  Warehouse  Elevator                     Address         Price  Price(USD)
# 0   63     1     True       True      True                     Shahran  1.850000e+09    61666.67
# 1   60     1     True       True      True                     Shahran  1.850000e+09    61666.67
# 2   79     2     True       True      True                      Pardis  5.500000e+08    18333.33
# 3   95     2     True       True      True               Shahrake Qods  9.025000e+08    30083.33
# 4  123     2     True       True      True              Shahrake Gharb  7.000000e+09   233333.33
# 5   70     2     True       True     False  North Program Organization  2.050000e+09    68333.33
# 6   87     2     True       True      True                      Pardis  6.000000e+08    20000.00
# 7   59     1     True       True      True                     Shahran  2.150000e+09    71666.67
# 8   54     2     True       True     False                    Andisheh  4.930000e+08    16433.33
# 9   71     1     True       True      True      West Ferdows Boulevard  2.370000e+09    79000.00

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# ده سطر آخر دیتافریم را چاپ کنید.
#     </font>
# </div>

# %%
df.tail(10)
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address         Price  Price(USD)
# 3469   74     2     True       True      True              Mehran  4.070000e+09   135666.67
# 3470   97     2     True       True      True             Shahran  2.700000e+09    90000.00
# 3471   94     2     True       True      True            Niavaran  8.450000e+09   281666.67
# 3472  113     3     True       True      True         Ostad Moein  3.170000e+09   105666.67
# 3473   63     1     True       True     False         Feiz Garden  1.890000e+09    63000.00
# 3474   86     2     True       True      True  Southern Janatabad  3.500000e+09   116666.67
# 3475   83     2     True       True      True            Niavaran  6.800000e+09   226666.67
# 3476   75     2    False      False     False              Parand  3.650000e+08    12166.67
# 3477  105     2     True       True      True              Dorous  5.600000e+09   186666.67
# 3478   82     2    False       True      True              Parand  3.600000e+08    12000.00

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ده سطر از دیتافریم را به صورت تصادفی (Random) انتخاب کرده و آن‌ها را در قالب یک دیتافریم با نام sample_df ذخیره کرده و آن را خروجی دهید.
#     </font>
# </div>

# %%
sample_df = df.sample(n=10)
sample_df
# Out:
#      Area  Room  Parking  Warehouse  Elevator                 Address         Price  Price(USD)
# 3206  135     3     True       True      True                Niavaran  9.000000e+09   300000.00
# 2200   67     2    False       True     False                  Karoon  1.070000e+09    35666.67
# 1827  300     4     True       True      True             Saadat Abad  3.000000e+10  1000000.00
# 3321  110     3     True       True      True               West Pars  6.550000e+09   218333.33
# 826   140     3     True       True      True                  Jordan  7.700000e+09   256666.67
# 3295   72     2     True       True     False                     NaN  9.000000e+08    30000.00
# 3103  115     2     True       True      True                  Jordan  6.200000e+09   206666.67
# 1440   88     2     True       True      True  West Ferdows Boulevard  3.100000e+09   103333.33
# 1337   90     2     True       True      True            Shahr-e-Ziba  4.150000e+09   138333.33
# 22     65     1     True       True      True                 Shahran  1.880000e+09    62666.67

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# با یک دستور، اطلاعاتی کلی همانند نام ستون‌ها، تعداد indexها، تعداد سلول‌های non-null و... راجع به دیتافریم را بدست اورید.    </font>
# </div>

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3479 entries, 0 to 3478
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Area        3479 non-null   object
#  1   Room        3479 non-null   int64
#  2   Parking     3479 non-null   bool
#  3   Warehouse   3479 non-null   bool
#  4   Elevator    3479 non-null   bool
#  5   Address     3456 non-null   object
#  6   Price       3479 non-null   float64
#  7   Price(USD)  3479 non-null   float64
# dtypes: bool(3), float64(2), int64(1), object(2)
# memory usage: 146.2+ KB
# None

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         با یک دستور، اطلاعاتی کلی همانند مقدار ماکزیمم، مینیمم، میانگین، چارک‌ها و... راجع به ستون‌های دیتافریم بدست آورید.
#     </font>
# </div>

# %%
print(df.describe())
# Out:
#               Room         Price    Price(USD)
# count  3479.000000  3.479000e+03  3.479000e+03
# mean      2.079908  5.359023e+09  1.786341e+05
# std       0.758275  8.099935e+09  2.699978e+05
# min       0.000000  3.600000e+06  1.200000e+02
# 25%       2.000000  1.418250e+09  4.727500e+04
# 50%       2.000000  2.900000e+09  9.666667e+04
# 75%       2.000000  6.000000e+09  2.000000e+05
# max       5.000000  9.240000e+10  3.080000e+06

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         تعداد سلول‌های خالی در هر ستون از دیتافریم را خروجی دهید.
#     </font>
# </div>

# %%
print(df.isnull().sum().sum())  
df.isna().sum()
# Out:
# 23
# Area           0
# Room           0
# Parking        0
# Warehouse      0
# Elevator       0
# Address       23
# Price          0
# Price(USD)     0
# dtype: int64

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# آن سلول‌هایی که خالی هستند را از دیتافریم حذف کنید و دیتافریم جدید را جایگزین قبلی کنید.    </font>
# </div>

# %%
df = df.dropna()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         با یک دستور، جنس متغیر ذخیره‌شده در هر ستون از دیتافریم را نشان دهید.
#     </font>
# </div>

# %%
print(df.dtypes)
# Out:
# Area           object
# Room            int64
# Parking          bool
# Warehouse        bool
# Elevator         bool
# Address        object
# Price         float64
# Price(USD)    float64
# dtype: object

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# جنس مقادیر ستون‌های  Area و Price  و Price(USD) را از رشته به مقدار عددی تغییر دهید و دیتافریم جدید را جایگزین قبلی کنید.    </font>
# </div>

# %%
df[['Area', 'Price', 'Price(USD)']] = df[['Area', 'Price', 'Price(USD)']].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ستون‌هایی که جنس متغیر آن‌ها از نوع Boolean است را به مقادیر عددی تغییر دهید و دیتافریم جدید را جایگزین قبلی کنید. (به ازای True مقدار 1 و به ازای False مقدار 0 جایگزین شود.)
#     </font>
# </div>

# %%
bool_columns = ['Parking', 'Warehouse', 'Elevator']
df[bool_columns] = df[bool_columns].astype(int)
df
# Out:
#        Area  Room  Parking  Warehouse  Elevator             Address         Price  Price(USD)
# 0      63.0     1        1          1         1             Shahran  1.850000e+09    61666.67
# 1      60.0     1        1          1         1             Shahran  1.850000e+09    61666.67
# 2      79.0     2        1          1         1              Pardis  5.500000e+08    18333.33
# 3      95.0     2        1          1         1       Shahrake Qods  9.025000e+08    30083.33
# 4     123.0     2        1          1         1      Shahrake Gharb  7.000000e+09   233333.33
# ...     ...   ...      ...        ...       ...                 ...           ...         ...
# 3474   86.0     2        1          1         1  Southern Janatabad  3.500000e+09   116666.67
# 3475   83.0     2        1          1         1            Niavaran  6.800000e+09   226666.67
# 3476   75.0     2        0          0         0              Parand  3.650000e+08    12166.67
# 3477  105.0     2        1          1         1              Dorous  5.600000e+09   186666.67
# 3478   82.0     2        0          1         1              Parand  3.600000e+08    12000.00
#
# [3456 rows x 8 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         دیتافریم جدیدی تشکیل دهید به طوری که نام ستون‌های دیتافریم اصلی در ابتدای سطرها قرار گیرد و اطلاعاتی همانند min , max , mean و... که در قسمت‌های قبلی بدست آوردیم را به عنوان ستون‌های دیتافریم جدید قرار دهید. این دیتافریم جدید را در متغیری با نام df_T ذخیره کنید و چاپ کنید.
#     </font>
# </div>

# %%
df_info = df.describe().transpose()
df_info = pd.DataFrame({
    'Count': df_info['count'],
    'Mean': df_info['mean'],
    'Std': df_info['std'],
    'Min': df_info['min'],
    '25%': df_info['25%'],
    '50%': df_info['50%'],
    '75%': df_info['75%'],
    'Max': df_info['max']
})

df_info
# Out:
#              Count          Mean           Std        Min           25%           50%           75%           Max
# Area        3450.0  1.069174e+02  6.955098e+01       30.0  6.900000e+01  9.000000e+01  1.200000e+02  9.290000e+02
# Room        3456.0  2.081308e+00  7.597228e-01        0.0  2.000000e+00  2.000000e+00  2.000000e+00  5.000000e+00
# Parking     3456.0  8.475116e-01  3.595457e-01        0.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# Warehouse   3456.0  9.149306e-01  2.790254e-01        0.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# Elevator    3456.0  7.873264e-01  4.092579e-01        0.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# Price       3456.0  5.379957e+09  8.121729e+09  3600000.0  1.420000e+09  2.900000e+09  6.000000e+09  9.240000e+10
# Price(USD)  3456.0  1.793319e+05  2.707243e+05      120.0  4.733333e+04  9.666667e+04  2.000000e+05  3.080000e+06

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نام ستون‌های دیتافریم را در یک لیست با نام column_names ذخیره کنید و سپس لیست را چاپ کنید.
#     </font>
# </div>

# %%
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['Area', 'Room', 'Parking', 'Warehouse', 'Elevator', 'Address', 'Price', 'Price(USD)']

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         یک دیکشنری از نام ستون‌ها تشکیل داده و نام هر ستون را به عنوان key و نام هر ستون به صورت Pascal case را به عنوان value آن در نظر بگیرید.(این
#         دیکشنری در مراحل بعدی مورد استفاده قرار می‌گیرد.)
#         <br>
#         </font>
#         <font face="IranSansX" size=2>
#         <a href="https://stackoverflow.com/questions/17326185/what-are-the-different-kinds-of-cases">می‌توانید از این لینک برای آشنایی با Case Styleها استفاده کنید.</a>
#     </font>
# </div>

# %%
column_dict = {}
for col in df.columns:
    column_dict[col] = col.title().replace('_', '')

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نام ستون‌هایی که طول آن‌ها از 8 کارکتر کمتر است را خروجی دهید.
#     </font>
# </div>

# %%
short = []
for col in df.columns:
    if len(col) < 8:
        short.append(col)
print(short)
# Out:
# ['Area', 'Room', 'Parking', 'Address', 'Price']

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# نام تمامی ستون‌ها را به صورت یک رشته‌ که نام هر ستون با کارکتر '-' از دیگری جدا شده، خروجی دهید.    </font>
# </div>

# %%
column_names = '-'.join(df.columns)
print(column_names)
# Out:
# Area-Room-Parking-Warehouse-Elevator-Address-Price-Price(USD)

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# با استفاده از دیکشنری ایجاد شده در مراحل قبل، نام ستون‌های دیتافریم را به صورت Pascal case تغییر دهید و در df ذخیره کنید.
#     </font>
# </div>

# %%
pascal_case = {col: col.title().replace('_', '') for col in column_names}

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ستون‌های مربوط به قیمت را حذف کرده و دیتافریم حاصل را در متغیری به نام df_without_price ذخیره کنید.
#     </font>
# </div>

# %%
df_without_price = df.drop(['Price', 'Price(USD)'], axis=1)

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         دیتافریم df_without_price را چاپ کنید.
#     </font>
# </div>

# %%
df_without_price
# Out:
#        Area  Room  Parking  Warehouse  Elevator             Address
# 0      63.0     1        1          1         1             Shahran
# 1      60.0     1        1          1         1             Shahran
# 2      79.0     2        1          1         1              Pardis
# 3      95.0     2        1          1         1       Shahrake Qods
# 4     123.0     2        1          1         1      Shahrake Gharb
# ...     ...   ...      ...        ...       ...                 ...
# 3474   86.0     2        1          1         1  Southern Janatabad
# 3475   83.0     2        1          1         1            Niavaran
# 3476   75.0     2        0          0         0              Parand
# 3477  105.0     2        1          1         1              Dorous
# 3478   82.0     2        0          1         1              Parand
#
# [3456 rows x 6 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ستون‌های Area و Room و Price را در قالب یک دیتافریم جدید خروجی دهید.
#     </font>
# </div>

# %%
new_df = df.loc[:, ['Area', 'Room', 'Price']]
new_df
# Out:
#        Area  Room         Price
# 0      63.0     1  1.850000e+09
# 1      60.0     1  1.850000e+09
# 2      79.0     2  5.500000e+08
# 3      95.0     2  9.025000e+08
# 4     123.0     2  7.000000e+09
# ...     ...   ...           ...
# 3474   86.0     2  3.500000e+09
# 3475   83.0     2  6.800000e+09
# 3476   75.0     2  3.650000e+08
# 3477  105.0     2  5.600000e+09
# 3478   82.0     2  3.600000e+08
#
# [3456 rows x 3 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# سطرهایی از دیتافریم df که index زوج دارند را در قالب یک دیتافریم خروجی دهید.
#     </font>
# </div>

# %%
New_df = df.iloc[::2,:]
New_df
# Out:
#        Area  Room  Parking  Warehouse  Elevator         Address         Price  Price(USD)
# 0      63.0     1        1          1         1         Shahran  1.850000e+09    61666.67
# 2      79.0     2        1          1         1          Pardis  5.500000e+08    18333.33
# 4     123.0     2        1          1         1  Shahrake Gharb  7.000000e+09   233333.33
# 6      87.0     2        1          1         1          Pardis  6.000000e+08    20000.00
# 8      54.0     2        1          1         0        Andisheh  4.930000e+08    16433.33
# ...     ...   ...      ...        ...       ...             ...           ...         ...
# 3469   74.0     2        1          1         1          Mehran  4.070000e+09   135666.67
# 3471   94.0     2        1          1         1        Niavaran  8.450000e+09   281666.67
# 3473   63.0     1        1          1         0     Feiz Garden  1.890000e+09    63000.00
# 3475   83.0     2        1          1         1        Niavaran  6.800000e+09   226666.67
# 3477  105.0     2        1          1         1          Dorous  5.600000e+09   186666.67
#
# [1728 rows x 8 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         تعداد مقادیر متمایز موجود در هر ستون را در قالب یک دیکشنری با نام دلخواه ذخیره کنید و خروجی دهید.(در دیکشنری key برابر است با نام ستون و value تعداد مقادیر متمایز موجود در آن است.)
#     </font>
# </div>

# %%
counts_dict = {}
for col in df.columns:
    counts_dict[col] = len(df[col].value_counts())
print(counts_dict)
# Out:
# {'Area': 237, 'Room': 6, 'Parking': 2, 'Warehouse': 2, 'Elevator': 2, 'Address': 192, 'Price': 930, 'Price(USD)': 928}

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         تمامی مقادیر متمایز موجود در ستون Address را در قالب یک لیست خروجی دهید.
#     </font>
# </div>

# %%
address_values = df['Address'].unique().tolist()
print(address_values)
# Out:
# ['Shahran', 'Pardis', 'Shahrake Qods', 'Shahrake Gharb', 'North Program Organization', 'Andisheh', 'West Ferdows Boulevard', 'Narmak', 'Saadat Abad', 'Zafar', 'Islamshahr', 'Pirouzi', 'Shahrake Shahid Bagheri', 'Moniriyeh', 'Velenjak', 'Amirieh', 'Southern Janatabad', 'Salsabil', 'Zargandeh', 'Feiz Garden', 'Water Organization', 'ShahrAra', 'Gisha', 'Ray', 'Abbasabad', 'Ostad Moein', 'Farmanieh', 'Parand', 'Punak', 'Qasr-od-Dasht', 'Aqdasieh', 'Pakdasht', 'Railway', 'Central Janatabad', 'East Ferdows Boulevard', 'Pakdasht KhatunAbad', 'Sattarkhan', 'Baghestan', 'Shahryar', 'Northern Janatabad', 'Daryan No', 'Southern Program Organization', 'Rudhen', 'West Pars', 'Afsarieh', 'Marzdaran', 'Dorous', 'Sadeghieh', 'Chahardangeh', 'Baqershahr', 'Jeyhoon', 'Lavizan', 'Shams Abad', 'Fatemi', 'Keshavarz Boulevard', 'Kahrizak', 'Qarchak', 'Northren Jamalzadeh', 'Azarbaijan', 'Bahar', 'Persian Gulf Martyrs Lake', 'Beryanak', 'Heshmatieh', 'Elm-o-Sanat', 'Golestan', 'Shahr-e-Ziba', 'Pasdaran', 'Chardivari', 'Gheitarieh', 'Kamranieh', 'Gholhak', 'Heravi', 'Hashemi', 'Dehkade Olampic', 'Damavand', 'Republic', 'Zaferanieh', 'Qazvin Imamzadeh Hassan', 'Niavaran', 'Valiasr', 'Qalandari', 'Amir Bahador', 'Ekhtiarieh', 'Ekbatan', 'Absard', 'Haft Tir', 'Mahallati', 'Ozgol', 'Tajrish', 'Abazar', 'Koohsar', 'Hekmat', 'Parastar', 'Lavasan', 'Majidieh', 'Southern Chitgar', 'Karimkhan', 'Si Metri Ji', 'Karoon', 'Northern Chitgar', 'East Pars', 'Kook', 'Air force', 'Sohanak', 'Komeil', 'Azadshahr', 'Zibadasht', 'Amirabad', 'Dezashib', 'Elahieh', 'Mirdamad', 'Razi', 'Jordan', 'Mahmoudieh', 'Shahedshahr', 'Yaftabad', 'Mehran', 'Nasim Shahr', 'Tenant', 'Chardangeh', 'Fallah', 'Eskandari', 'Shahrakeh Naft', 'Ajudaniye', 'Tehransar', 'Nawab', 'Yousef Abad', 'Northern Suhrawardi', 'Villa', 'Hakimiyeh', 'Nezamabad', 'Garden of Saba', 'Tarasht', 'Azari', 'Shahrake Apadana', 'Araj', 'Vahidieh', 'Malard', 'Shahrake Azadi', 'Darband', 'Vanak', 'Tehran Now', 'Darabad', 'Eram', 'Atabak', 'Sabalan', 'SabaShahr', 'Shahrake Madaen', 'Waterfall', 'Ahang', 'Salehabad', 'Pishva', 'Enghelab', 'Islamshahr Elahieh', 'Ray - Montazeri', 'Firoozkooh Kuhsar', 'Ghoba', 'Mehrabad', 'Southern Suhrawardi', 'Abuzar', 'Dolatabad', 'Hor Square', 'Taslihat', 'Kazemabad', 'Robat Karim', 'Ray - Pilgosh', 'Ghiyamdasht', 'Telecommunication', 'Mirza Shirazi', 'Gandhi', 'Argentina', 'Seyed Khandan', 'Shahrake Quds', 'Safadasht', 'Khademabad Garden', 'Hassan Abad', 'Chidz', 'Khavaran', 'Boloorsazi', 'Mehrabad River River', 'Varamin - Beheshti', 'Shoosh', 'Thirteen November', 'Darakeh', 'Aliabad South', 'Alborz Complex', 'Firoozkooh', 'Vahidiyeh', 'Shadabad', 'Naziabad', 'Javadiyeh', 'Yakhchiabad']

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# یک دیکشنری با نام دلخواه ایجاد کنید که key آن برابر با نام ستون‌های دیتافریم و value آن برابر است با لیستی از مقدار متمایز موجود در آن ستون از دیتافریم.در آخر دیکشنری را چاپ کنید.
#     </font>
# </div>

# %%
dictionary = df.apply(lambda x: x.unique().tolist()).to_dict()
print(dictionary)
# Out:
# {'Area': [63.0, 60.0, 79.0, 95.0, 123.0, 70.0, 87.0, 59.0, 54.0, 71.0, 68.0, 64.0, 136.0, 155.0, 140.0, 42.0, 93.0, 65.0, 99.0, 105.0, 160.0, 77.0, 110.0, 100.0, 90.0, 49.0, 96.0, 67.0, 62.0, 55.0, 129.0, 109.0, 58.0, 150.0, 130.0, 88.0, 51.0, 113.0, 98.0, 75.0, 61.0, 72.0, 122.0, 215.0, 101.0, 53.0, 74.0, 114.0, 151.0, 300.0, 76.0, 148.0, 40.0, 128.0, 94.0, 97.0, 137.0, 85.0, 78.0, 48.0, 82.0, 120.0, 139.0, 66.0, 80.0, 44.0, 50.0, 121.0, 141.0, 127.0, 180.0, 158.0, 144.0, 245.0, 190.0, 108.0, 117.0, 200.0, 125.0, 236.0, 220.0, 86.0, 84.0, 106.0, 320.0, 154.0, 210.0, 124.0, 83.0, 270.0, 104.0, 103.0, 165.0, 135.0, 132.0, 81.0, 153.0, 166.0, 175.0, 170.0, 115.0, 118.0, 116.0, 43.0, 230.0, 91.0, 126.0, 450.0, 500.0, 145.0, 112.0, 192.0, 164.0, 265.0, 92.0, 143.0, 350.0, 335.0, 235.0, 225.0, 221.0, 312.0, 188.0, 198.0, 650.0, 179.0, 256.0, 257.0, 167.0, 246.0, 168.0, 280.0, 69.0, 400.0, 660.0, 213.0, 57.0, 102.0, 133.0, 73.0, 134.0, 191.0, 282.0, 89.0, 111.0, 147.0, 157.0, 283.0, nan, 863.0, 415.0, 173.0, 162.0, 156.0, 171.0, 261.0, 45.0, 161.0, 46.0, 107.0, 420.0, 131.0, 185.0, 250.0, 216.0, 680.0, 750.0, 202.0, 138.0, 38.0, 56.0, 197.0, 52.0, 365.0, 181.0, 146.0, 240.0, 142.0, 303.0, 203.0, 204.0, 255.0, 194.0, 600.0, 377.0, 231.0, 195.0, 176.0, 290.0, 149.0, 238.0, 226.0, 574.0, 360.0, 37.0, 465.0, 403.0, 405.0, 41.0, 228.0, 177.0, 310.0, 193.0, 287.0, 929.0, 550.0, 47.0, 380.0, 182.0, 119.0, 705.0, 222.0, 152.0, 209.0, 232.0, 900.0, 201.0, 174.0, 39.0, 172.0, 35.0, 32.0, 211.0, 258.0, 700.0, 163.0, 208.0, 253.0, 33.0, 330.0, 212.0, 345.0, 530.0, 630.0, 30.0, 205.0, 285.0, 186.0], 'Room': [1, 2, 3, 0, 4, 5], 'Parking': [1, 0], 'Warehouse': [1, 0], 'Elevator': [1, 0], 'Address': ['Shahran', 'Pardis', 'Shahrake Qods', 'Shahrake Gharb', 'North Program Organization', 'Andisheh', 'West Ferdows Boulevard', 'Narmak', 'Saadat Abad', 'Zafar', 'Islamshahr', 'Pirouzi', 'Shahrake Shahid Bagheri', 'Moniriyeh', 'Velenjak', 'Amirieh', 'Southern Janatabad', 'Salsabil', 'Zargandeh', 'Feiz Garden', 'Water Organization', 'ShahrAra', 'Gisha', 'Ray', 'Abbasabad', 'Ostad Moein', 'Farmanieh', 'Parand', 'Punak', 'Qasr-od-Dasht', 'Aqdasieh', 'Pakdasht', 'Railway', 'Central Janatabad', 'East Ferdows Boulevard', 'Pakdasht KhatunAbad', 'Sattarkhan', 'Baghestan', 'Shahryar', 'Northern Janatabad', 'Daryan No', 'Southern Program Organization', 'Rudhen', 'West Pars', 'Afsarieh', 'Marzdaran', 'Dorous', 'Sadeghieh', 'Chahardangeh', 'Baqershahr', 'Jeyhoon', 'Lavizan', 'Shams Abad', 'Fatemi', 'Keshavarz Boulevard', 'Kahrizak', 'Qarchak', 'Northren Jamalzadeh', 'Azarbaijan', 'Bahar', 'Persian Gulf Martyrs Lake', 'Beryanak', 'Heshmatieh', 'Elm-o-Sanat', 'Golestan', 'Shahr-e-Ziba', 'Pasdaran', 'Chardivari', 'Gheitarieh', 'Kamranieh', 'Gholhak', 'Heravi', 'Hashemi', 'Dehkade Olampic', 'Damavand', 'Republic', 'Zaferanieh', 'Qazvin Imamzadeh Hassan', 'Niavaran', 'Valiasr', 'Qalandari', 'Amir Bahador', 'Ekhtiarieh', 'Ekbatan', 'Absard', 'Haft Tir', 'Mahallati', 'Ozgol', 'Tajrish', 'Abazar', 'Koohsar', 'Hekmat', 'Parastar', 'Lavasan', 'Majidieh', 'Southern Chitgar', 'Karimkhan', 'Si Metri Ji', 'Karoon', 'Northern Chitgar', 'East Pars', 'Kook', 'Air force', 'Sohanak', 'Komeil', 'Azadshahr', 'Zibadasht', 'Amirabad', 'Dezashib', 'Elahieh', 'Mirdamad', 'Razi', 'Jordan', 'Mahmoudieh', 'Shahedshahr', 'Yaftabad', 'Mehran', 'Nasim Shahr', 'Tenant', 'Chardangeh', 'Fallah', 'Eskandari', 'Shahrakeh Naft', 'Ajudaniye', 'Tehransar', 'Nawab', 'Yousef Abad', 'Northern Suhrawardi', 'Villa', 'Hakimiyeh', 'Nezamabad', 'Garden of Saba', 'Tarasht', 'Azari', 'Shahrake Apadana', 'Araj', 'Vahidieh', 'Malard', 'Shahrake Azadi', 'Darband', 'Vanak', 'Tehran Now', 'Darabad', 'Eram', 'Atabak', 'Sabalan', 'SabaShahr', 'Shahrake Madaen', 'Waterfall', 'Ahang', 'Salehabad', 'Pishva', 'Enghelab', 'Islamshahr Elahieh', 'Ray - Montazeri', 'Firoozkooh Kuhsar', 'Ghoba', 'Mehrabad', 'Southern Suhrawardi', 'Abuzar', 'Dolatabad', 'Hor Square', 'Taslihat', 'Kazemabad', 'Robat Karim', 'Ray - Pilgosh', 'Ghiyamda ...

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         تعداد دفعات تکرار هر مقدار متمایز در ستون Address را مشخص کنید و نتایج را در یک دیکشنری ذخیره کرده و خروجی دهید.(در دیکشنری key برابر با نام مقادیر متمایز ستون Address و value برابر با تعداد دفعات تکرار آن است.)
#     </font>
# </div>

# %%
Adress_counts = df['Address'].value_counts().to_dict()
print(Adress_counts)
# Out:
# {'Punak': 161, 'Pardis': 146, 'West Ferdows Boulevard': 145, 'Gheitarieh': 141, 'Shahran': 130, 'Saadat Abad': 129, 'Parand': 127, 'Shahr-e-Ziba': 109, 'Southern Janatabad': 93, 'Central Janatabad': 91, 'Jeyhoon': 91, 'Persian Gulf Martyrs Lake': 88, 'Andisheh': 83, 'Ostad Moein': 83, 'East Ferdows Boulevard': 74, 'Shahrake Qods': 69, 'Niavaran': 68, 'Pasdaran': 67, 'Pirouzi': 63, 'Salsabil': 60, 'Shahrake Gharb': 59, 'Farmanieh': 57, 'Heravi': 46, 'Ekhtiarieh': 42, 'Islamshahr': 39, 'Yousef Abad': 38, 'Feiz Garden': 38, 'Northern Janatabad': 33, 'Qasr-od-Dasht': 28, 'North Program Organization': 27, 'Zaferanieh': 27, 'Beryanak': 25, 'Narmak': 25, 'Aqdasieh': 25, 'Pakdasht': 25, 'Azarbaijan': 24, 'Tenant': 23, 'Damavand': 23, 'Southern Program Organization': 23, 'Abazar': 23, 'Si Metri Ji': 23, 'Velenjak': 22, 'Marzdaran': 22, 'Karoon': 20, 'Jordan': 18, 'Elahieh': 17, 'Northern Chitgar': 16, 'Kahrizak': 16, 'Golestan': 16, 'Mirdamad': 15, 'Northren Jamalzadeh': 14, 'Kamranieh': 14, 'Amirabad': 14, 'Dorous': 13, 'Hashemi': 13, 'Shahryar': 13, 'Sattarkhan': 12, 'Amirieh': 12, 'Qazvin Imamzadeh Hassan': 11, 'Qalandari': 11, 'Rudhen': 11, 'West Pars': 11, 'Railway': 11, 'Komeil': 11, 'Air force': 10, 'Zafar': 10, 'Gholhak': 10, 'Ozgol': 10, 'Gisha': 9, 'Dezashib': 9, 'Ray': 9, 'Dehkade Olampic': 9, 'Araj': 9, 'Fallah': 9, 'Kook': 9, 'East Pars': 8, 'Tehransar': 8, 'Parastar': 8, 'Mehran': 8, 'Baghestan': 8, 'Shams Abad': 8, 'Valiasr': 7, 'Tajrish': 7, 'Razi': 7, 'Ekbatan': 7, 'Hor Square': 6, 'Tarasht': 6, 'Afsarieh': 6, 'Sadeghieh': 6, 'Absard': 6, 'Ajudaniye': 5, 'Hakimiyeh': 5, 'Shahedshahr': 5, 'Shahrake Quds': 5, 'Azadshahr': 5, 'ShahrAra': 5, 'Qarchak': 5, 'Southern Chitgar': 5, 'Keshavarz Boulevard': 4, 'Amir Bahador': 4, 'Northern Suhrawardi': 4, 'Tehran Now': 4, 'Water Organization': 4, 'Zargandeh': 4, 'Koohsar': 4, 'Republic': 4, 'Mahallati': 4, 'Lavasan': 4, 'Heshmatieh': 4, 'Eskandari': 4, 'Seyed Khandan': 3, 'Khavaran': 3, 'Waterfall': 3, 'Darabad': 3, 'Abuzar': 3, 'Shahrakeh Naft': 3, 'Atabak': 3, 'Karimkhan': 3, 'Fatemi': 3, 'Yaftabad': 3, 'Mahmoudieh': 3, 'Daryan No': 3, 'Elm-o-Sanat': 3, 'Ghoba': 2, 'Shoosh': 2, 'Sabalan': 2, 'Ahang': 2, 'Shahrake Shahid Bagheri': 2, 'Pishva': 2, 'Chidz': 2, 'Nasim Shahr': 2, 'Moniriyeh': 2, 'Vanak': 2, 'Dolatabad': 2, 'Abbasabad': 2, 'Taslihat': 2, 'Argentina': 2, 'Robat Karim': 2, 'Southern Suhrawardi': 2, 'Lavizan': 2, 'Nezamabad': 2, 'Malard': 2, 'Vahidieh': 2, 'Majidieh': 2, 'Nawab': 2, 'Hekmat': 2, 'Haft Tir': 2, 'Garden of Saba': 2, 'Shahrake Azadi': 2, 'Vahidiyeh': 2, 'Darakeh': 1, 'Gandhi': 1, 'Javadiyeh': 1, 'Naziabad': 1, 'Shadabad': 1, 'Hassan Abad': 1, 'Safadasht': 1, 'Khademabad Garden': 1, 'Firoozkooh': 1, 'Alborz Complex': 1, 'Aliabad South': 1, 'Boloorsazi': 1, 'Mehrabad River River': 1, 'Varamin - Beheshti': 1, 'Thirteen November': 1, 'Telecommunication': 1, 'Mirza Shirazi': 1, 'Firoozkooh Kuhsar': 1, 'Ghiyamdasht': 1, 'Ray - Pilgosh': 1, 'Zibadasht': 1, 'Sohanak': 1, 'Villa': 1, 'Chardivari': 1, 'Azari': 1, 'Shahrake Apadana': 1, 'Bahar': 1, 'Darband': 1, 'Eram': 1, 'Baqershahr': 1, 'SabaShahr': 1, 'Shahrake Madaen': 1, 'Chahardangeh': 1, 'Salehabad': 1, 'Enghelab': 1, 'Islamshahr Elahieh': 1, 'Ray - Montazeri': 1, 'Chardangeh': 1, 'Mehrabad': 1, 'Pakdasht KhatunAbad': 1, 'Kazemabad': 1, 'Yakhchiabad': 1}

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ماکزیمم، مینیمم و طول بازه‌ی تغییرات مقادیر ستون‌هایی که متغیر آن‌ها عددی است را چاپ کنید.
#     </font>
# </div>

# %%
numeric_stats = df.describe()
change_intervals = numeric_stats.loc['max'] - numeric_stats.loc['min']
max_value = numeric_stats.loc['max']
min_value = numeric_stats.loc['min']
print(f'max_value:\n{max_value}\n\nmin_value:\n{min_value}\n\nchange intervals:\n{change_intervals}')
# Out:
# max_value:
# Area          9.290000e+02
# Room          5.000000e+00
# Parking       1.000000e+00
# Warehouse     1.000000e+00
# Elevator      1.000000e+00
# Price         9.240000e+10
# Price(USD)    3.080000e+06
# Name: max, dtype: float64
#
# min_value:
# Area               30.0
# Room                0.0
# Parking             0.0
# Warehouse           0.0
# Elevator            0.0
# Price         3600000.0
# Price(USD)        120.0
# Name: min, dtype: float64
#
# change intervals:
# Area          8.990000e+02
# Room          5.000000e+00
# Parking       1.000000e+00
# Warehouse     1.000000e+00
# Elevator      1.000000e+00
# Price         9.239640e+10
# Price(USD)    3.079880e+06
# dtype: float64

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         سطرهایی که مقدار Area آن‌ها از چارک اول مقادیر ستون Area کمتر است را در یک دیتافریم جدید با نام دلخواه ذخیره کرده و خروجی دهید.
#     </font>
# </div>

# %%
df['Area'] = pd.to_numeric(df['Area'], errors='coerce')
numeric_stats = df['Area'].describe()
quarter_value = numeric_stats.loc['25%']
filtered_df = df[df['Area'] < quarter_value].copy()
filtered_df
# Out:
#       Area  Room  Parking  Warehouse  Elevator                 Address         Price  Price(USD)
# 0     63.0     1        1          1         1                 Shahran  1.850000e+09    61666.67
# 1     60.0     1        1          1         1                 Shahran  1.850000e+09    61666.67
# 7     59.0     1        1          1         1                 Shahran  2.150000e+09    71666.67
# 8     54.0     2        1          1         0                Andisheh  4.930000e+08    16433.33
# 10    68.0     2        1          1         1  West Ferdows Boulevard  2.450000e+09    81666.67
# ...    ...   ...      ...        ...       ...                     ...           ...         ...
# 3461  55.0     1        1          1         1                   Punak  2.300000e+09    76666.67
# 3462  60.0     1        1          1         1  West Ferdows Boulevard  1.950000e+09    65000.00
# 3465  68.0     2        0          1         1                Beryanak  1.258000e+09    41933.33
# 3466  61.0     2        0          1         0                Andisheh  4.600000e+08    15333.33
# 3473  63.0     1        1          1         0             Feiz Garden  1.890000e+09    63000.00
#
# [861 rows x 8 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         همانند قسمت قبل، آن سطرهایی که Area آن‌ها از چارک اول کمتر است را شناسایی کرده و فقط مقادیر ستون‌های Area، Room و Price خروجی دهید.
#     </font>
# </div>

# %%
df['Area'] = pd.to_numeric(df['Area'], errors='coerce')
numeric_stats = df['Area'].describe()
quarter_value = numeric_stats.loc['25%']
filtered_df = df[df['Area'] < quarter_value].copy()
filtered_df[['Area', 'Room', 'Price']]
# Out:
#       Area  Room         Price
# 0     63.0     1  1.850000e+09
# 1     60.0     1  1.850000e+09
# 7     59.0     1  2.150000e+09
# 8     54.0     2  4.930000e+08
# 10    68.0     2  2.450000e+09
# ...    ...   ...           ...
# 3461  55.0     1  2.300000e+09
# 3462  60.0     1  1.950000e+09
# 3465  68.0     2  1.258000e+09
# 3466  61.0     2  4.600000e+08
# 3473  63.0     1  1.890000e+09
#
# [861 rows x 3 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         دیتافریم اولیه را برحسب ستون قیمت sort کنید و آن را در متغیری به نام df_sorted_by_price ذخیره کنید و در آخر خروجی دهید.
#     </font>
# </div>

# %%
df_sorted_by_price = df.sort_values(by='Price')
df_sorted_by_price
# Out:
#        Area  Room  Parking  Warehouse  Elevator     Address         Price  Price(USD)
# 136   160.0     1        0          0         0     Qarchak  3.600000e+06      120.00
# 2770   83.0     2        1          1         1       Ozgol  5.500000e+07     1833.33
# 731    75.0     2        1          1         1      Pardis  6.000000e+07     2000.00
# 2721  110.0     0        1          1         1      Parand  1.020000e+08     3400.00
# 2201   49.0     1        1          1         0    Andisheh  1.100000e+08     3666.67
# ...     ...   ...      ...        ...       ...         ...           ...         ...
# 1332  350.0     4        1          1         1    Niavaran  8.050000e+10  2683333.33
# 819   680.0     5        1          1         0  Ekhtiarieh  8.160000e+10  2720000.00
# 430   400.0     5        1          1         0     Lavasan  8.500000e+10  2833333.33
# 1810  705.0     5        1          1         0      Abazar  9.100000e+10  3033333.33
# 1707  420.0     4        1          1         1  Zaferanieh  9.240000e+10  3080000.00
#
# [3456 rows x 8 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# دیتافریم df_sorted_by_price را به صورت معکوس خروجی دهید.(از آخر به اول)    </font>
# </div>

# %%
df_sorted_by_price_desc = df_sorted_by_price.sort_values(by='Price', ascending=False)
print(df_sorted_by_price_desc)
# Out:
#        Area  Room  Parking  Warehouse  Elevator     Address         Price  Price(USD)
# 1707  420.0     4        1          1         1  Zaferanieh  9.240000e+10  3080000.00
# 1810  705.0     5        1          1         0      Abazar  9.100000e+10  3033333.33
# 430   400.0     5        1          1         0     Lavasan  8.500000e+10  2833333.33
# 819   680.0     5        1          1         0  Ekhtiarieh  8.160000e+10  2720000.00
# 1332  350.0     4        1          1         1    Niavaran  8.050000e+10  2683333.33
# ...     ...   ...      ...        ...       ...         ...           ...         ...
# 2201   49.0     1        1          1         0    Andisheh  1.100000e+08     3666.67
# 2721  110.0     0        1          1         1      Parand  1.020000e+08     3400.00
# 731    75.0     2        1          1         1      Pardis  6.000000e+07     2000.00
# 2770   83.0     2        1          1         1       Ozgol  5.500000e+07     1833.33
# 136   160.0     1        0          0         0     Qarchak  3.600000e+06      120.00
#
# [3456 rows x 8 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         سطرهایی که مقدار ستون Elevator برای آن‌ها True است را برحسب قیمت sort کنید و خروجی دهید.
#     </font>
# </div>

# %%
df_elevator_true_sorted = df[df['Elevator'] == True].sort_values(by='Price')
df_elevator_true_sorted
# Out:
#        Area  Room  Parking  Warehouse  Elevator     Address         Price  Price(USD)
# 2770   83.0     2        1          1         1       Ozgol  5.500000e+07     1833.33
# 731    75.0     2        1          1         1      Pardis  6.000000e+07     2000.00
# 2721  110.0     0        1          1         1      Parand  1.020000e+08     3400.00
# 1343   78.0     2        1          1         1      Parand  2.100000e+08     7000.00
# 3432   58.0     1        0          0         1      Parand  2.460000e+08     8200.00
# ...     ...   ...      ...        ...       ...         ...           ...         ...
# 2394  310.0     3        1          1         1    Aqdasieh  7.440000e+10  2480000.00
# 831   750.0     5        1          1         1  Mahmoudieh  7.500000e+10  2500000.00
# 3051  530.0     4        1          1         1      Dorous  7.950000e+10  2650000.00
# 1332  350.0     4        1          1         1    Niavaran  8.050000e+10  2683333.33
# 1707  420.0     4        1          1         1  Zaferanieh  9.240000e+10  3080000.00
#
# [2721 rows x 8 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         دیتافریم را برحسب Address گروه‌بندی کنید، سپس جمع Area خانه‌های هر گروه را محاسبه و خروجی دهید.
#     </font>
# </div>

# %%
df_grouped = df.groupby('Address')['Area'].sum()
df_grouped
# Out:
# Address
# Abazar         2885.0
# Abbasabad       150.0
# Absard         3100.0
# Abuzar          184.0
# Afsarieh        491.0
#                 ...
# Yousef Abad    4437.0
# Zafar          1879.0
# Zaferanieh     5293.0
# Zargandeh       485.0
# Zibadasht       115.0
# Name: Area, Length: 192, dtype: float64

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         دیتافریم را برحسب Address گروه‌بندی کنید، سپس میانگین Area خانه‌های هر گروه را با استفاده از Aggregate کردن گروه‌ها با تابع mean بیابید، سپس مقادیر بدست آمده را در یک دیتافریم جدید ذخیره کرده و خروجی دهید.
#     </font>
# </div>

# %%
df['Area'] = pd.to_numeric(df['Area'], errors='coerce')
grouped_df = df.groupby('Address')['Area'].mean().reset_index()
print(grouped_df)
# Out:
#          Address        Area
# 0         Abazar  125.434783
# 1      Abbasabad   75.000000
# 2         Absard  516.666667
# 3         Abuzar   61.333333
# 4       Afsarieh   81.833333
# ..           ...         ...
# 187  Yousef Abad  116.763158
# 188        Zafar  187.900000
# 189   Zaferanieh  196.037037
# 190    Zargandeh  121.250000
# 191    Zibadasht  115.000000
#
# [192 rows x 2 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         یک crosstab برحسب Room و Parking رسم کنید.
#     </font>
# </div>

# %%
crosstab = pd.crosstab(df['Room'], df['Parking'])
print(crosstab)
# Out:
# Parking    0     1
# Room
# 0          8     2
# 1        243   426
# 2        244  1699
# 3         26   705
# 4          1    69
# 5          5    28

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# یک crosstab برحسب Room و Warehouse رسم کنید.    </font>
# </div>

# %%
crosstab_df = pd.crosstab(df['Room'], df['Parking'])
print(crosstab_df)
# Out:
# Parking    0     1
# Room
# 0          8     2
# 1        243   426
# 2        244  1699
# 3         26   705
# 4          1    69
# 5          5    28

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         یک crosstab برحسب Room و Elevator رسم کنید.
#     </font>
# </div>

# %%
crosstab_df = pd.crosstab(df['Room'], df['Elevator'])
print(crosstab_df)
# Out:
# Elevator    0     1
# Room
# 0           8     2
# 1         282   387
# 2         352  1591
# 3          49   682
# 4          17    53
# 5          27     6

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نشان دهید خانه‌هایی که 0 اتاق، 1 اتاق،....، 5اتاق دارند، به طور میانگین چه قیمتی دارند.
#     </font>
# </div>

# %%
average_price_by_rooms = df.groupby('Room').aggregate({'Price': 'mean'})
print(average_price_by_rooms)
# Out:
#              Price
# Room
# 0     7.860500e+09
# 1     1.707481e+09
# 2     3.330303e+09
# 3     1.093869e+10
# 4     2.560033e+10
# 5     3.373439e+10

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# دیتافریم را برحسب Room و Parking گروه‌بندی کرده و میانگین قیمت هرکدام را حساب کنید.(ترجیحاً با استفاده از Aggregate کردن این کار را انجام دهید.)
#     </font>
# </div>

# %%
grouped_df = df.groupby(['Room', 'Parking']).agg({'Price': 'mean'})
print(grouped_df)
# Out:
#                      Price
# Room Parking
# 0    0        9.769750e+09
#      1        2.235000e+08
# 1    0        1.139678e+09
#      1        2.031369e+09
# 2    0        1.501674e+09
#      1        3.592920e+09
# 3    0        5.107865e+09
#      1        1.115373e+10
# 4    0        6.200000e+09
#      1        2.588149e+10
# 5    0        9.999000e+09
#      1        3.797286e+10

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# یک ستون جدید به نام Score به دیتافریم اصلی اضافه کنید، به طوری که مقدار آن برای هرسطر برابر است با جمع مقادیر ستون‌های Parking و Warehouse و Elevator (البته با فرض این که مقادیر ستون‌ها را در مراحل قبل از True/False به 0و1 تغییر داده‌اید.)
#     </font>
# </div>

# %%
df['Parking'] = df['Parking'].astype(int)
df['Warehouse'] = df['Warehouse'].astype(int)
df['Elevator'] = df['Elevator'].astype(int)
df['Score'] = df['Parking'] + df['Warehouse'] + df['Elevator']

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         محاسبه کنید که چند درصد خانه‌هایی که مساحت کمتر از 100مترمربع دارند، دارای پارکینگ هستند؟
#     </font>
# </div>

# %%
df['Area'] = pd.to_numeric(df['Area'], errors='coerce')
percentage1 = (df[(df['Area'] < 100) & (df['Parking'] == 1)].shape[0] / df[df['Area'] < 100].shape[0]) * 100
print(percentage1)
# Out:
# 76.93459810284573

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         محاسبه کنید که چند درصد از خانه‌های این دیتافریم حداقل یکی از سه ویژگی پارکینگ، انباری یا آسانسور را دارند؟
#     </font>
# </div>

# %%
percentage2 = (df[(df['Parking'] == 1) | (df['Warehouse'] == 1) | (df['Elevator'] == 1)].shape[0] / df.shape[0]) * 100
print(percentage2)
# Out:
# 96.29629629629629

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# خانه‌هایی از دیتافریم که تعداد اتاق‌های آن‌ها از 2 بیشتر است و حداقل یکی از سه ویژگی پارکینگ، انباری یا آسانسور را دارند، در قالب یک دیتافریم خروجی بدهید.    </font>
# </div>

# %%
filtered_df1 = df[(df['Room'] > 2) & ((df['Parking'] == 1) | (df['Warehouse'] == 1) | (df['Elevator'] == 1))]
filtered_df1
# Out:
#        Area  Room  Parking  Warehouse  Elevator                 Address         Price  Price(USD)  Score
# 13    136.0     3        1          1         1             Saadat Abad  1.100000e+10   366666.67      3
# 16    155.0     3        1          1         1                  Narmak  6.700000e+09   223333.33      3
# 18    140.0     3        1          1         1  West Ferdows Boulevard  6.400000e+09   213333.33      3
# 25    160.0     3        1          1         1                Velenjak  1.494500e+10   498166.67      3
# 44    130.0     3        1          1         0                ShahrAra  5.000000e+09   166666.67      2
# ...     ...   ...      ...        ...       ...                     ...           ...         ...    ...
# 3453  180.0     3        1          1         0               Marzdaran  1.080000e+10   360000.00      2
# 3457  123.0     3        1          1         1                Velenjak  1.250000e+10   416666.67      3
# 3458  148.0     3        1          1         1               Daryan No  6.000000e+09   200000.00      3
# 3463  133.0     3        1          0         1          Shahrake Gharb  1.000000e+10   333333.33      2
# 3472  113.0     3        1          1         1             Ostad Moein  3.170000e+09   105666.67      3
#
# [821 rows x 9 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         خانه‌هایی که حداقل 2 و حداکثر 4 اتاق دارند و دارای پارکینگ هستند را در قالب یک دیتافریم خروجی دهید.
#     </font>
# </div>

# %%
filtered_df2 = df[(df['Room'] >= 2) & (df['Room'] <= 4) & (df['Parking'] == 1)]
filtered_df2
# Out:
#        Area  Room  Parking  Warehouse  Elevator                     Address         Price  Price(USD)  Score
# 2      79.0     2        1          1         1                      Pardis  5.500000e+08    18333.33      3
# 3      95.0     2        1          1         1               Shahrake Qods  9.025000e+08    30083.33      3
# 4     123.0     2        1          1         1              Shahrake Gharb  7.000000e+09   233333.33      3
# 5      70.0     2        1          1         0  North Program Organization  2.050000e+09    68333.33      2
# 6      87.0     2        1          1         1                      Pardis  6.000000e+08    20000.00      3
# ...     ...   ...      ...        ...       ...                         ...           ...         ...    ...
# 3471   94.0     2        1          1         1                    Niavaran  8.450000e+09   281666.67      3
# 3472  113.0     3        1          1         1                 Ostad Moein  3.170000e+09   105666.67      3
# 3474   86.0     2        1          1         1          Southern Janatabad  3.500000e+09   116666.67      3
# 3475   83.0     2        1          1         1                    Niavaran  6.800000e+09   226666.67      3
# 3477  105.0     2        1          1         1                      Dorous  5.600000e+09   186666.67      3
#
# [2473 rows x 9 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# یک ستون به دیتافریم اضافه کنید و در آن حاصل تقسیم Price بر Area را ذخیره کنید، سپس دیتافریم را برحسب این ستون sort کنید. حال بررسی کنید که 50 خانه‌ی اول این دیتافریم sort شده مربوط به کدام Addressهای متمایز هستند. این Addressها را در قالب یک لیست خروجی دهید.
#     </font>
# </div>

# %%
df['Price_Per_Area'] = df['Price'] / df['Area']
sorted_df = df.sort_values('Price_Per_Area')
distinct_addresses = sorted_df['Address'].head(50).unique().tolist()
print(distinct_addresses)
# Out:
# ['Qarchak', 'Ozgol', 'Pardis', 'Parand', 'Andisheh', 'Persian Gulf Martyrs Lake', 'Northern Chitgar', 'Pasdaran', 'Malard', 'Pakdasht', 'Shahryar', 'Pishva', 'Saadat Abad', 'Shahedshahr', 'Shahrake Qods']

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         <b>
#         <font color=#006bcf size=5>فاز دوم پروژه: </font>
#         <font color=#006bcf size=5>
# Data Visualization
#             </font>
#          </b>
#         <br><br>
#          <font face="IranSansX" size=3>
#         بخش تصویرسازی داده‌ها در این پروژه، به دانشجوان فرصت می‌دهد تا با استفاده از ابزارها و تکنیک‌های مختلف، داده‌های خود را به شکل‌های بصری جذاب و قابل فهم ترسیم کنند. این بخش از پروژه امکان می‌دهد تا دانشجوان با استفاده از نمودارها، نقشه‌ها، چارت‌ها و دیگر روش‌های تصویری، اطلاعات و الگوهای مهم موجود در داده‌های خود را به روشی کارآمد و شفاف برای مخاطبان مختلف به نمایش بگذارند. این فرایند نه‌تنها به دانشجوان کمک می‌کند تا داده‌های خود را بهبود دهند و بازنمایی مناسبی از آن‌ها ارائه دهند، بلکه به آن‌ها این امکان را می‌دهد تا ارتباطات قوی‌تری بین داده‌ها را ایجاد کرده و الگوها یا تفاوت‌های مهم را به دیگران به شیوه‌ای واضح و قابل فهم نشان دهند. استفاده از تصاویر و گرافیک‌های مختلف به دانشجوان کمک می‌کند تا ارتباطات خود را بهبود بخشند و به دیگران کمک کنند تا داده‌ها را با یک دید بصری جذاب و موثرتر درک کنند.
#         </font>
#         <hr/>
#         <hr/>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         <b><font color=#cf0000 size=4>نکات مهم فاز دوم</font></b>
#         <hr/>
#         <ul>
#             <li>در این فاز اجباری است که تمامی نمودارهایی که رسم می‌کنید دارای title و label و ... باشد.(جدای از این که داخل متن سوال اشاره شده یا خیر.)</li>
#             <li>همچنین لازم است که scale تمامی نمودارها را با استفاده از دستوراتی همانند xlim و ylim طوری تنظیم کنید که نمودار شکل و شمایل خوبی داشته باشد.</li>
#         </ul>
#         <img src="https://github.com/MoeeinAali/FOP2023-Python-Project-SUT/blob/main/public/pic1.jpg?raw=true" style="width:75%;">
#                 <hr>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار پراکندگی Price برحسب Area را رسم کنید.(نام هر محور را با label مشخص کنید.)
#     </font>
# </div>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
plt.scatter(df['Area'], df['Price(USD)'], alpha=0.5)
plt.title('Price in Terms of Area')
plt.xlabel('Area')
plt.ylabel('Price (Usd)')
plt.grid(True)
plt.xlim(0, df['Area'].max() + 10)
plt.ylim(0, df['Price(USD)'].max() + 1000000)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# نمودار قبلی را با رنگی غیر از رنگ default رسم کنید.    </font>
# </div>

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df['Area'], df['Price(USD)'], alpha=0.5, color='green')  
plt.title('Price in Terms of Area')
plt.xlabel('Area')
plt.ylabel('Price (USD)')
plt.grid(True)
plt.xlim(0, df['Area'].max() + 10)
plt.ylim(0, df['Price(USD)'].max() + 1000000)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار قبلی را طوری رسم کنید که نقاط با کارکتر ستاره (*) نشان داده شوند.
#     </font>
# </div>

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df['Area'], df['Price(USD)'], alpha=0.5, color='green', marker='*')  
plt.title('Price in Terms of Area')
plt.xlabel('Area')
plt.ylabel('Price (USD)')
plt.grid(True)
plt.xlim(0, df['Area'].max() + 10)
plt.ylim(0, df['Price(USD)'].max() + 1000000)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# نمودار پراکندگی Price برحسب Room را همانند نمودار قبلی با ویژگی‌های فوق به صورت یکجا رسم کنید.    </font>
# </div>

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df['Room'], df['Price'], alpha=0.5)  
plt.title('Price in Terms of Score')
plt.xlabel('Room')
plt.ylabel('Price')
plt.grid(True)
plt.xlim(0, df['Room'].max() + 1)
plt.ylim(0, df['Price'].max() + 1000000)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار پراکندگی Price را برحسب ستون Score که خودمان در قسمت‌های قبل ایجاد کردیم رسم کنید.
#     </font>
# </div>

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df['Score'], df['Price(USD)'], alpha=0.5)  
plt.title('Price in Terms of Score')
plt.xlabel('Score')
plt.ylabel('Price (USD)')
plt.grid(True)
plt.xlim(0, df['Score'].max() + 1)
plt.ylim(0, df['Price(USD)'].max() + 1000000)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار توزیع فراوانی را برای ستون Price رسم کنید. بازه‌ی تغییرات قیمت را به 30 قسمت تقسیم کرده و در نمودار نشان دهید.
#     </font>
# </div>

# %%
plt.figure(figsize=(10, 6))
plt.title('Frequency Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.hist(df['Price'], bins=30, color='skyblue', edgecolor='black')
plt.show()


plt.figure(figsize=(10, 6))
plt.title('Frequency Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.hist(df['Price'], bins=30, color='skyblue', edgecolor='black')
plt.xlim(df['Price'].min(), df['Price'].max())
plt.ylim(0, 100)  
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# برای نمودار قسمت قبل، نمودار تخمین چگالی توزیع هم‌زمان (KDE) را رسم کنید.(این نمودار یک تخمین صاف و پیوسته از توزیع احتمال داده‌ها را نشان می‌دهد.)    </font>
# </div>

# %%
plt.figure(figsize=(12, 8))
sns.kdeplot(df['Price(USD)'], fill=True)
plt.title('Kernel Density Estimate (KDE) of Price')
plt.xlabel('Price (USD)')
plt.ylabel('Density')
plt.grid(True)
plt.xlim(0, df['Price(USD)'].max() + 1000000)
plt.ylim(0, 0.000002)  
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         توضیح دهید که کاربرد نمودار توزیع فراوانی چیست؟
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;font-size:small;">
# 	<font face="IranSansX" size=2 color=#006bcf>
# متن پاسخ خود را اینجا paste کنید.
#     </font>
# </div>
# نمودار توزیع فراوانی به تحلیل شکل و توزیع داده‌ها کمک می‌کند:
# ممکن است نشان دهد که داده‌ها چگونه در مقایسه با یک توزیع معین قرار دارند.
# با نمایش فراوانی داده‌ها در بازه‌های مختلف، این نمودار به تفکیک توزیع داده و شناخت بازه‌های احتمالی کمک می‌کند.
# ممکن است الگوهای خاصی در توزیع داده‌ها کشف شود که به تحلیل و تفسیر دقیق‌تر داده‌ها کمک کند.
# نمودار توزیع فراوانی به دلیل ساختار گرافیکی‌اش، ارائه اطلاعات به یک شکل تجسمی و قابل فهم فراهم می‌کند.
# این نمودار به شناسایی انحراف‌ها و پرتکرارها در داده‌ها کمک می‌کند.

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# با استفاده از نمودار Pairplot برای هر دو جفت ستون موجود در دیتافریم یک نمودار پراکندگی به همراه KDE رسم کنید.
#     </font>
# </div>

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(15, 15))  
sns.pairplot(df, kind='scatter', diag_kind='kde')
plt.suptitle('Scatter Plot with KDE - Pairplot for All Columns', y=1.02)
plt.subplots_adjust(top=0.9)  
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# ابتدا ماتریس همبستگی (Correlation Matrix) دیتافریم را با استفاده از توابع آماده بسازید و ذخیره کنید، سپس نمودار Heatmap را بر اساس این ماتریس رسم کنید.
#     </font>
# </div>

# %%
numeric_df = df.select_dtypes(include='number')
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار Heatmap را به گونه‌ای رسم کنید که مقدار ماتریس همبستگی در هر خانه از نمودار نشان داده شود و از پالت رنگی RdYlGn برای رسم نمودار استفاده شود.
#     </font>
# </div>

# %%
numeric_df = df.select_dtypes(include='number')
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='RdYlGn', fmt=".2f", linewidths=.5)
plt.title('Correlation Materix Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# توضیح دهید که کاربرد Heatmap چیست؟
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;font-size:small;">
# 	<font face="IranSansX" size=2 color=#006bcf>
# متن پاسخ خود را اینجا paste کنید.
#     </font>
# </div>

# %% [markdown]
# Heatmap یا نمودار حرارتی یک نمودار دوبعدی است که از رنگ‌ها برای نمایش دادن فراوانی، یا مقدار عددی داده‌ها در یک ماتریس استفاده می‌کند. در این نمودار، هر سلول ماتریس با یک رنگ نمایان‌گر مقدار متناسب داده است.
# Heatmap به طور گسترده در زمینه‌های مختلف مورد استفاده قرار می‌گیرد، از جمله علوم داده، آمار، برنامه‌ریزی، مهندسی، و زمینه‌های بهینه‌سازی. این نمودار به صورت گرافیکی اطلاعات را به تصویر می‌کشد و به تحلیل الگوها، ارتباطات، و تغییرات در داده‌ها کمک می‌کند.
# رنگ‌ها در Heatmap به صورت گرمایی نمایش داده می‌شوند، به طوری که رنگ‌های داغتر (مانند قرمز) نشان‌دهنده مقادیر بزرگتر و رنگ‌های سردتر (مانند آبی) نشان‌دهنده مقادیر کمتر هستند. این نمودار به تفسیر سریع و قابل فهم داده‌های پیچیده و ماتریسی کمک می‌کند.

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         برای ستون Parking نمودار Pie Chart را به گونه‌ای رسم کنید که هر بخش نمودار یک رنگ دلخواه از طیف سبز داشته باشد و بخشی که فراوانی کمتری دارد از نمودار explode شود و هر بخش نمودار یک label داشته باشد.
#     </font>
# </div>

# %%
parking_counts = df['Parking'].value_counts()
colors = ['lightgreen', 'skyblue']
explode = (0, 0.1)
plt.figure(figsize=(8, 8))
plt.pie(parking_counts, labels=parking_counts.index, autopct='%1.1f%%', colors=colors, explode=explode, startangle=90)
plt.title('Distribution of Parking Availability', fontsize=18)
plt.xlabel('Parking Availability', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# توضیح دهید که کاربرد Piechart چیست؟
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;font-size:small;">
# 	<font face="IranSansX" size=2 color=#006bcf>
# متن پاسخ خود را اینجا paste کنید.
#     </font>
# </div>

# %% [markdown]
# نمودار دایره‌ای یا Pie Chart یک نمودار آماری است که به صورت دایره‌ای طراحی می‌شود و برای نمایش توزیع درصدی یا فراوانی اجزاء یک مجموعه مورد استفاده قرار می‌گیرد. این نوع نمودار به ازای هر اجزاء (دسته) از یک مجموعه، یک قطاع از دایره اختصاص می‌یابد که اندازه آن به نسبت درصد یا فراوانی آن دسته نسبت به مجموعه کل را نمایش می‌دهد.
# مزیت این نمودار در نمایش به وضوح توزیع درصدی اجزاء و درک سریع از نسبت‌ها و اهمیت هر قسمت نسبت به کل است.
# Pie Chart برای نشان دادن سهم هر دسته به کل، نسبت‌ها و توازن در یک مجموعه داده به‌خصوص مناسب است و برای جلب توجه به تغییرات نسبی بین اجزاء مفید است. این نمودار معمولاً در تحلیل‌های ساده و نمایش گرافیکی اطلاعات درست استفاده می‌شود.

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         یک نمودار سه قسمتی از نوع Pie Chart رسم کنید. هربخش از این نمودار نشان دهنده توزیع یکی از سه متغیر Warehouse , Parking , Elevator است. نمودار را به گونه‌ای رسم کنید که طیف رنگی هر متغیر با دیگری فرق کند و هر بخش نمودار دارای label مناسب باشد و بخشی که فراوانی کمتری دارد از نمودار explode شود.
#     </font>
# </div>

# %%
labels = ['Warehouse', 'Parking', 'Elevator']
colors = ['orange', 'skyblue', 'lightgreen']
counts = [df['Warehouse'].sum(), df['Parking'].sum(), df['Elevator'].sum()]
explode = (0.1, 0, 0)  
plt.figure(figsize=(8, 8))
plt.pie(counts, labels=labels, colors=colors, autopct='%1.1f%%', explode=explode, shadow=True, startangle=140)
plt.title('Distribution of Warehouse, Parking, and Elevator')
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# نمودار جعبه‌ای را برای ستون Price به گونه‌ای رسم کنید که رنگ آن قرمز باشد و نمودار دارای title و xlabel باشد.
#     </font>
# </div>

# %%
plt.figure(figsize=(6, 10))
sns.set(style="whitegrid")
sns.boxplot(y='Price', data=df, color='red')
plt.title('Vertical Box Plot of Price Column', fontsize=16)
plt.xlabel('Value', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.ylim([df['Price'].min() - 0.1 * df['Price'].min(), df['Price'].max() + 0.1 * df['Price'].max()])
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# نمودار قبلی را به گونه‌ای رسم کنید که قطر خطوط و اندازه فونت نوشته‌های نمودار را به میزان دلخواه زیاد کنید.    </font>
# </div>

# %%
fig, ax = plt.subplots(figsize=(6, 10))
boxplot = ax.boxplot(df['Price'], vert=True, patch_artist=True, widths=0.7,
                     boxprops=dict(facecolor='red'),
                     medianprops=dict(color='black'),
                     whiskerprops=dict(linewidth=2),
                     capprops=dict(linewidth=2),
                     flierprops=dict(marker='o', markerfacecolor='red', markersize=8))

ax.set_title('Vertical Box Plot for Price', fontsize=18)
ax.set_ylabel('Price', fontsize=16)
ax.xaxis.set_visible(False)

for key in boxplot.keys():
    for line in boxplot[key]:
        line.set_linewidth(2)
ax.set_ylim([df['Price'].min() - 0.1 * df['Price'].min(), df['Price'].max() + 0.1 * df['Price'].max()])
ax.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار histogram را برای ستون Room رسم کنید و برای آن label و title و رنگ مناسب مشخص کنید.
#     </font>
# </div>

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Room'], bins=10, edgecolor='black', color='skyblue')
plt.title('Histogram for Room Column')
plt.xlabel('Number of Rooms')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xlim(0, df['Room'].max() + 1)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         یک نمودار سه قسمتی از نوع histogram رسم کنید. هر بخش از این نمودار نشان دهنده‌ی توزیع یکی از سه متغیر Elevator , Parking , Warehouse است.  نمودار را به گونه‌ای رسم کنید که طیف رنگی هر متغیر با دیگری فرق کند و هر بخش نمودار دارای label مناسب باشد.
#     </font>
# </div>

# %%
variables = ['Elevator', 'Parking', 'Warehouse']
fig, ax = plt.subplots(figsize=(10, 6))
colors = ['skyblue', 'orange', 'lightgreen']
width = 0.2  

for i, variable in enumerate(variables):
    bins = np.arange(-0.5, 2, 1) + i * width
    ax.hist(df[variable], bins=bins, edgecolor='black', color=colors[i], label=f'{variable} Availability', alpha=0.7)

ax.set_title('Three-Part Histogram for Elevator, Parking, and Warehouse')
ax.set_xlabel('Availability')
ax.set_ylabel('Frequency')
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.set_xticks(np.arange(0, 3) + width)
ax.set_xticklabels(variables)
ax.legend()
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ابتدا دامنه تغییرات ستون Price را محاسبه کنید و آن را به 4 بازه مساوی با نام‌های cheap , AveUnderMean , AveUpperMean , Expensive تقسیم کنید. به هر بازه تعداد خانه‌هایی که قیمتشان در این بازه قرار دارد را نسبت دهید و در آخر نمودار countplot را برای این بازه‌ها رسم کنید.
#     </font>
# </div>

# %%
price_range = df['Price'].max() - df['Price'].min()
interval_size = price_range / 4
cheap = df['Price'].min() + interval_size
AveUnderMean = cheap + interval_size
AveUpperMean = AveUnderMean + interval_size
Expensive = AveUpperMean + interval_size

df['PriceCategory'] = pd.cut(df['Price'], bins=[df['Price'].min(), cheap, AveUnderMean, AveUpperMean, df['Price'].max()],
                             labels=['cheap', 'AveUnderMean', 'AveUpperMean', 'Expensive'])

plt.figure(figsize=(10, 6))
sns.countplot(x='PriceCategory', data=df, order=['cheap', 'AveUnderMean', 'AveUpperMean', 'Expensive'])
plt.title('Distribution of House Prices')
plt.xlabel('Price Category')
plt.ylabel('Number of Houses')
#plt.ylim(0, 300) 
plt.show()


price_range = df['Price'].max() - df['Price'].min()
interval_size = price_range / 4
cheap = df['Price'].min() + interval_size
AveUnderMean = cheap + interval_size
AveUpperMean = AveUnderMean + interval_size
Expensive = AveUpperMean + interval_size

df['PriceCategory'] = pd.cut(df['Price'], bins=[df['Price'].min(), cheap, AveUnderMean, AveUpperMean, df['Price'].max()],
                             labels=['cheap', 'AveUnderMean', 'AveUpperMean', 'Expensive'])

plt.figure(figsize=(10, 6))
sns.countplot(x='PriceCategory', data=df, order=['cheap', 'AveUnderMean', 'AveUpperMean', 'Expensive'])
plt.title('Distribution of House Prices')
plt.xlabel('Price Category')
plt.ylabel('Number of Houses')
plt.ylim(0, 100) 
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ابتدا 2 درصد از داده‌های ستون Price را به صورت تصادفی انتخاب کنید و سپس نمودار خط‌ شکسته را برای این داده‌ها رسم کنید.(محورها دارای label باشند و رنگ نمودار قرمز باشد.)
#     </font>
# </div>

# %%
random_sample = df['Price'].sample(frac=0.02, random_state=42)
plt.figure(figsize=(10, 6))
plt.plot(random_sample.index, random_sample, marker='o', linestyle='-', color='red')
plt.title('Broken Line Graph for 2% Random Sample of Price Column')
plt.xlabel('Index')
plt.ylabel('Price')
plt.grid(True)
plt.tight_layout()
plt.xlim([random_sample.index.min(), random_sample.index.max()])
plt.ylim([random_sample.min(), random_sample.max()])
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         همانطور که میبینید نمودار قبلی ظاهر خوبی ندارد و شرط تابع بودن را نقض کرده است، داده‌های تصادفی مرحله قبل را به گونه‌ای sort کنید نمودار ما تبدیل به یک تابعی شود که اکیدا یکنوا نیست و نوسان دارد.
#     </font>
# </div>

# %%
random_sample = df['Price'].sample(frac=0.02, random_state=42)
random_sample = np.sort(random_sample)
plt.figure(figsize=(10, 6))
plt.plot(random_sample, marker='o', linestyle='-', color='red')
plt.title('Broken Line Graph for 2% Random Sample of Price Column')
plt.xlabel('Index')
plt.ylabel('Price')
plt.grid(True)
plt.tight_layout()
plt.xlim([0, len(random_sample)])
plt.ylim([random_sample.min(), random_sample.max()])
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار قسمت قبل را به گونه‌ای رسم کنید که نقاط شکستگی نمودار با یک دایره با رنگ آبی نشان داده شوند.
#     </font>
# </div>

# %%
random_sample = df['Price'].sample(frac=0.02, random_state=42)
random_sample = np.sort(random_sample)
plt.figure(figsize=(10, 6))
plt.plot(random_sample, marker='o', linestyle='-', color='red', markerfacecolor='blue')  # Change markerfacecolor to blue
plt.title('Broken Line Graph for 2% Random Sample of Price Column')
plt.xlabel('Index')
plt.ylabel('Price')
plt.grid(True)
plt.tight_layout()
plt.xlim([0, len(random_sample)])
plt.ylim([random_sample.min(), random_sample.max()])
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار خط شکسته‌ی Price(USD) برحسب Area را رسم کنید.
#     </font>
# </div>

# %%
df_sorted = df.sort_values(by='Area')
plt.figure(figsize=(12, 8))
plt.plot(df_sorted['Area'], df_sorted['Price(USD)'], marker='o')
plt.title('Sorted Broken Line Chart of Price(USD) by Area')
plt.xlabel('Area')
plt.ylabel('Price(USD)')
plt.xlim([df_sorted['Area'].min(), df_sorted['Area'].max() + 10])
plt.ylim([df_sorted['Price(USD)'].min(), df_sorted['Price(USD)'].max()])
plt.grid(True)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         به نمودار رسم شده در قسمت قبل، نمودار روند تغییرات مرتبه اول(خطی) را اضافه کنید.(برای پیدا کردن ضرایب رگرسیون می‌توانید از تابع polyfit در کتابخانه numpy استفاده کنید.)
#     </font>
# </div>

# %%
df_sorted = df.sort_values(by='Area')
df_cleaned = df_sorted[['Area', 'Price(USD)']].dropna()
df_cleaned['Area'] = (df_cleaned['Area'] - df_cleaned['Area'].mean()) / df_cleaned['Area'].std()
slope, intercept = np.polyfit(df_cleaned['Area'], df_cleaned['Price(USD)'], 1, rcond=1e-10)
linear_fit = np.polyval([slope, intercept], df_cleaned['Area'])
print(f'Slope = {slope}, Intercept = {intercept}')
plt.figure(figsize=(12, 8))
plt.plot(df_cleaned['Area'], df_cleaned['Price(USD)'], marker='o', label='Original Data')
plt.plot(df_cleaned['Area'], linear_fit, label='Linear Fit')
plt.title('Sorted Broken Line Chart with Linear Fit of Price(USD) by Area')
plt.xlabel('Area (Standardized)')
plt.ylabel('Price(USD)')
plt.legend()
plt.xlim([df_cleaned['Area'].min(), df_cleaned['Area'].max() + 0.1])
plt.ylim([df_cleaned['Price(USD)'].min(), df_cleaned['Price(USD)'].max()])
plt.grid(True)
plt.show()
# Out:
# Slope = 195729.18467819458, Intercept = 179185.42034492697

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار روند تغییرات خطی که در قسمت قبل رسم کردیم را به صورت خط‌چین با رنگ قرمز رسم کنید.
#     </font>
# </div>

# %%
df_sorted = df.sort_values(by='Area')
df_cleaned = df_sorted[['Area', 'Price(USD)']].dropna()
df_cleaned['Area'] = (df_cleaned['Area'] - df_cleaned['Area'].mean()) / df_cleaned['Area'].std()
slope, intercept = np.polyfit(df_cleaned['Area'], df_cleaned['Price(USD)'], 1, rcond=1e-10)
linear_fit = np.polyval([slope, intercept], df_cleaned['Area'])
print(f'Slope = {slope}, Intercept = {intercept}')
plt.figure(figsize=(12, 8))
plt.plot(df_cleaned['Area'], df_cleaned['Price(USD)'], marker='o', label='Original Data')
plt.plot(df_cleaned['Area'], linear_fit, linestyle='--', label='Linear Fit')
plt.title('Sorted Broken Line Chart with Linear Fit of Price(USD) by Area')
plt.xlabel('Area (Standardized)')
plt.ylabel('Price(USD)')
plt.legend()
plt.xlim([df_cleaned['Area'].min(), df_cleaned['Area'].max() + 0.1])
plt.ylim([df_cleaned['Price(USD)'].min(), df_cleaned['Price(USD)'].max()])
plt.grid(True)
plt.show()
# Out:
# Slope = 195729.18467819458, Intercept = 179185.42034492697

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار Barplot را برای ستون Price برحسب ستون Room رسم کنید.(نمودار باید دارای title و label مناسب باشد.)
#     </font>
# </div>

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Room', y='Price', data=df)
plt.title('Barplot of Price by Room')
plt.xlabel('Number of Rooms')
plt.ylabel('Price (USD)')
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         توضیح دهید که کاربرد Barplot چیست؟
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;font-size:small;">
# 	<font face="IranSansX" size=2 color=#006bcf>
# متن پاسخ خود را اینجا paste کنید.
#     </font>
# </div>

# %% [markdown]
# نمودار ستونی شامل مجموعه ­ای از ستون­هاست که با فاصله یکنواختی در کنار هم قرار می­گیرند و عرض این ستون­ها با هم برابرند و هر ستون مختص یک طبقه از متغیر و طول آن متناسب با فراوانی یا درصد آن طبقه است.  در محور افقی گروه­ هایی که قرار است با هم مقایسه شوند مشخص می­شود و در محور عمودی عددهایی متناسب با تعداد هر گروه مشخص می­شود.
# نمودارهای میله‌ای یکی از ابزارهای قوی در تجزیه و تحلیل داده‌های گروه‌بندی شده هستند. این نمودارها به شما امکان می‌دهند تا مقدار یک متغیر در گروه‌های مختلف را با یکدیگر مقایسه کنید و با طراحی بهینه و استفاده از رنگ‌ها و اندازه‌های مختلف، این نمودارها می‌توانند اطلاعات زیادی را به شما منتقل کنند.
# استفاده از این نوع نمودارها برای تحلیل آماری داده‌ها، نمایش توزیع فراوانی‌ها، مقایسه گروه‌ها و موارد دیگر در تحلیل داده‌ها بسیار کمک‌کننده است.
# میله‌ها در نمودار به طور عمودی یا افقی می‌توانند نمایش داده شوند.
